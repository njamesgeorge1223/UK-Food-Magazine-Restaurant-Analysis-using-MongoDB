# %%
#*******************************************************************************************
 #
 #  File Name:  NoSQLAnalysis.ipynb
 #
 #  File Description:
 #      This interactive Python notebook, NoSQLAnalysis.ipynb, uses the Python module,
 #      PyMongo to analyze restaurant ratings data in a MongoDB database, uk_food, 
 #      for the editors of a food magazine, Eat Safe, Love.
 #
 #
 #  Date            Description                             Programmer
 #  ----------      ------------------------------------    ------------------
 #  09/18/2023      Initial Development                     N. James George
 #
 #******************************************************************************************/

import NoSQLAnalysisFunctions as local_function

import PyFunctions as function
import PyLogFunctions as log_function
import PyLogSubRoutines as log_subroutine

import pandas as pd

from pprint import pprint
from pymongo import MongoClient
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
CONSTANT_LOCAL_FILE_NAME \
    = 'NoSQLAnalysis.ipynb'


log_subroutine \
    .SetLogMode \
        (False)

log_subroutine \
    .SetDebugMode \
        (False)

log_subroutine \
    .SetImageMode \
        (False)


log_subroutine \
    .BeginProgramExecution \
        ('NoSQLAnalysis')

# %% [markdown]
# # <br> **Section 1: Database and Jupyter Notebook Set Up**

# %% [markdown]
# ## **1.1: MongoDB Client**

# %%
# This line of code creates an instance of a MongoDB client and
# assigns it to a variable.
currentPyMongoClientObject \
    = MongoClient \
        (port \
             = 27017)


log_function \
    .DebugReturnObjectWriteObject \
        (currentPyMongoClientObject)

# %% [markdown]
# ## **1.2: MongoDB Database Confirmation**

# %%
# These lines of code list all the databases in MongoDB and confirm 
# the existence of the database, uk_food.
log_subroutine \
    .PrintAndLogWriteText \
        ('\033[1m' \
         + 'This is a List of the current MongoDB Databases:\n' \
         + '\033[0m' \
         + str \
            (currentPyMongoClientObject \
                .list_database_names()))


if 'uk_food' in currentPyMongoClientObject.list_database_names():
     
    log_subroutine \
        .PrintAndLogWriteText \
            ('\033[1m' \
             + "\nThe MongoDB Database, 'uk_food', is in the List " \
             + 'of MongoDB Databases.' \
             + '\033[0m')
    
else:
    
    log_subroutine \
        .PrintAndLogWriteText \
            ('\033[1m' \
             + "\nThe MongoDB Database, 'uk_food', is NOT in the List. " \
             + 'Please run NoSQLSetup.ipynb before proceeding!' \
             + '\033[0m')
# Out:
# This is a List of the current MongoDB Databases:
# ['admin', 'config', 'epa', 'fruits_db', 'local', 'met', 'petsitly_marketing', 'uk_food']
#
# The MongoDB Database, 'uk_food', is in the List of MongoDB Databases.

# %% [markdown]
# ## **1.3: MongoDB Database**

# %%
# This line of code creates a PyMongo Database Object for the database, 
# uk_food, and assigns it to a variable.
currentPyMongoDatabaseObject \
    = currentPyMongoClientObject \
        .uk_food
    
    
log_function \
    .DebugReturnObjectWriteObject \
        (str(currentPyMongoDatabaseObject))

# %% [markdown]
# ## **1.4: MongoDB Collection Confirmation**

# %%
# These lines of code list all the Collections in the MongoDB database, 
# uk_food, and confirm the existence of the Collection, establishments.
log_subroutine \
    .PrintAndLogWriteText \
        ('\033[1m' \
         + 'Here is a List of the current Collections ' \
         + 'in the MongoDB Database, uk_food:\n' \
         + '\033[0m' \
         + str \
            (currentPyMongoDatabaseObject \
                .list_collection_names()))


if 'establishments' in currentPyMongoDatabaseObject.list_collection_names():
     
    log_subroutine \
        .PrintAndLogWriteText \
            ('\033[1m' \
             + "\nThe Collection, 'establishments', " \
             + "is in the MongoDB Database, 'uk_food'." \
             + '\033[0m')
    
else:
    
    log_subroutine \
        .PrintAndLogWriteText \
            ('\033[1m' \
             + "\nThe Collection, 'establishments', " \
             + "is NOT in the MongoDB database, 'uk_food'. " \
             + 'Please run NoSQLSetup.ipynb before proceeding!' \
             + '\033[0m')
# Out:
# Here is a List of the current Collections in the MongoDB Database, uk_food:
# ['establishments']
#
# The Collection, 'establishments', is in the MongoDB Database, 'uk_food'.

# %% [markdown]
# ## **1.5: MongoDB Collection**

# %%
# This line of code creates a PyMongo Collection Object for the Collection,
# establishments, and assigns it to a variable.
currentPyMongoCollectionObject \
    = currentPyMongoDatabaseObject \
        .establishments


log_function \
    .DebugReturnObjectWriteObject \
        (str(currentPyMongoCollectionObject))

# %% [markdown]
# # <br> **Section 2: Exploratory Analysis**

# %% [markdown]
# ## **2.1 -- Which establishments have a hygiene score equal to 20 (the worst possible rating)?**

# %% [markdown]
# ### **Number of Establishments from `count_documents`**

# %%
# These lines of code query and display the number of establishments 
# with the lowest hygiene score, 20.
queryDictionary \
    = {'scores.Hygiene': 20}

numberOfEstablishmentsInteger \
    = currentPyMongoCollectionObject \
        .count_documents \
            (queryDictionary)

log_subroutine \
    .PrintAndLogWriteText \
        ('\033[1m' \
         + 'There are {:,} establishments with a hygiene score equal to 20.' \
            .format \
                (numberOfEstablishmentsInteger) \
         + '\033[0m')
# Out:
# There are 41 establishments with a hygiene score equal to 20.

# %% [markdown]
# ### **Display First Document**

# %%
# This query returns all the documents where the restaurant 
# has a hygiene score equal to 20.
queryResultsDictionaryList \
    = currentPyMongoCollectionObject \
        .find \
            (queryDictionary)


# This line of code displays the first document from the query 
# results.
pprint \
    (queryResultsDictionaryList[0])
# Out:
# {'AddressLine1': '5-6 Southfields Road',
#  'AddressLine2': 'Eastbourne',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'BusinessName': 'The Chase Rest Home',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4613.888288172291,
#  'FHRSID': 110681,
#  'LocalAuthorityBusinessID': '4029',
#  'LocalAuthorityCode': '102',
#  'LocalAuthorityEmailAddress': 'Customerfirst@eastbourne.gov.uk',
#  'LocalAuthorityName': 'Eastbourne',
#  'LocalAuthorityWebSite': 'http://www.eastbourne.gov.uk/foodratings',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'BN21 1BU',
#  'RatingDate': '2021-09-23',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': None,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('654b006a8942454b1967ebb8'),
#  'geocode': {'latitude': 50.769705, 'longitude': 0.27694},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/110681',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 20}}

# %% [markdown]
# ### **Worst Hygiene Establishments Data Set**

# %%
# This line of code creates the DataFrame.
worstHygieneDataFrame \
    = pd.DataFrame \
        (list \
            (queryResultsDictionaryList))

# This function rearranges the columns in the DataFrame.
worstHygieneDataFrame \
    = local_function \
        .ReturnReorderedColumnsNoSQLDataFrame \
            (worstHygieneDataFrame)


log_function \
    .DebugReturnObjectWriteObject \
        (worstHygieneDataFrame)

# %% [markdown]
# ### **Number of Rows in Worst Hygiene Establishments Data Set**

# %%
log_subroutine \
    .PrintAndLogWriteText \
        ('\033[1m' \
         + 'The number of rows in the Lowest Hygiene Establishments ' \
         + 'DataFrame is {:,}.' \
                .format \
                    (len \
                         (worstHygieneDataFrame)) \
         + '\033[0m')
# Out:
# The number of rows in the Lowest Hygiene Establishments DataFrame is 41.

# %% [markdown]
# ### **Worst Hygiene Establishments' Locations Data Set**

# %%
worstHygieneLocationsDataFrame \
    = local_function \
        .ReturnLocationsDataFrame \
            (worstHygieneDataFrame,
             'Hygiene')


log_function \
    .DebugReturnObjectWriteObject \
        (worstHygieneLocationsDataFrame)

# %% [markdown]
# ### **Display Worst Hygiene Establishments**

# %%
# This line of code displays a formatted DataFrame hiding those columns 
# that are not necessary for editorial decisions.
captionString \
    = 'Table 2.1: Worst Hygiene Establishments'

currentStylerObject \
    = function \
        .ReturnStylerObjectStandardFormat \
            (worstHygieneDataFrame.head(10),
             captionString,
             hideFlagBooleanParameter = True) \
                .format({'RatingValue': '{:,.0f}'}) \
                .hide \
                    (['_id',
                      'ChangesByServerID',
                      'FHRSID',
                      'LocalAuthorityBusinessID',
                      'BusinessTypeID',
                      'geocode',
                      'Distance',
                      'RatingKey',
                      'RightToReply',
                      'SchemeType',
                      'LocalAuthorityCode',
                      'meta',
                      'links'],
                     axis = 1)

log_function \
    .ReturnStylerObjectSavePNGImage \
        (currentStylerObject,
         captionString)
# Out:
# <style type="text/css">
# #T_6fbff caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_6fbff_row0_col4, #T_6fbff_row0_col5, #T_6fbff_row0_col7, #T_6fbff_row0_col8, #T_6fbff_row0_col9, #T_6fbff_row0_col10, #T_6fbff_row0_col11, #T_6fbff_row0_col14, #T_6fbff_row0_col15, #T_6fbff_row0_col17, #T_6fbff_row0_col18, #T_6fbff_row0_col19, #T_6fbff_row0_col21, #T_6fbff_row0_col22, #T_6fbff_row0_col23, #T_6fbff_row1_col4, #T_6fbff_row1_col5, #T_6fbff_row1_col7, #T_6fbff_row1_col8, #T_6fbff_row1_col9, #T_6fbff_row1_col10, #T_6fbff_row1_col11, #T_6fbff_row1_col14, #T_6fbff_row1_col15, #T_6fbff_row1_col17, #T_6fbff_row1_col18, #T_6fbff_row1_col19, #T_6fbff_row1_col21, #T_6fbff_row1_col22, #T_6fbff_row1_col23, #T_6fbff_row2_col4, #T_6fbff_row2_col5, #T_6fbff_row2_col7, #T_6fbff_row2_col8, #T_6fbff_row2_col9, #T_6fbff_row2_col10, #T_6fbff_row2_col11, #T_6fbff_row2_col14, #T_6fbff_row2_col15, #T_6fbff_row2_col17, #T_6fbff_row2_col18, #T_6fbff_row2_col19, #T_6fbff_row2_col21, #T_6fbff_row2_col22, #T_6fbff_row2_col23, #T_6fbff_row3_col4, #T_6fbff_row3_col5, #T_6fbff_row3_col7, #T_6fbff_row3_col8, #T_6fbff_row3_col9, #T_6fbff_row3_col10, #T_6fbff_row3_col11, #T_6fbff_row3_col14, #T_6fbff_row3_col15, #T_6fbff_row3_col17, #T_6fbff_row3_col18, #T_6fbff_row3_col19, #T_6fbff_row3_col21, #T_6fbff_row3_col22, #T_6fbff_row3_col23, #T_6fbff_row4_col4, #T_6fbff_row4_col5, #T_6fbff_row4_col7, #T_6fbff_row4_col8, #T_6fbff_row4_col9, #T_6fbff_row4_col10, #T_6fbff_row4_col11, #T_6fbff_row4_col14, #T_6fbff_row4_col15, #T_6fbff_row4_col17, #T_6fbff_row4_col18, #T_6fbff_row4_col19, #T_6fbff_row4_col21, #T_6fbff_row4_col22, #T_6fbff_row4_col23, #T_6fbff_row5_col4, #T_6fbff_row5_col5, #T_6fbff_row5_col7, #T_6fbff_row5_col8, #T_6fbff_row5_col9, #T_6fbff_row5_col10, #T_6fbff_row5_col11, #T_6fbff_row5_col14, #T_6fbff_row5_col15, #T_6fbff_row5_col17, #T_6fbff_row5_col18, #T_6fbff_row5_col19, #T_6fbff_row5_col21, #T_6fbff_row5_col22, #T_6fbff_row5_col23, #T_6fbff_row6_col4, #T_6fbff_row6_col5, #T_6fbff_row6_col7, #T_6fbff_row6_col8, #T_6fbff_row6_col9, #T_6fbff_row6_col10, #T_6fbff_row6_col11, #T_6fbff_row6_col14, #T_6fbff_row6_col15, #T_6fbff_row6_col17, #T_6fbff_row6_col18, #T_6fbff_row6_col19, #T_6fbff_row6_col21, #T_6fbff_row6_col22, #T_6fbff_row6_col23, #T_6fbff_row7_col4, #T_6fbff_row7_col5, #T_6fbff_row7_col7, #T_6fbff_row7_col8, #T_6fbff_row7_col9, #T_6fbff_row7_col10, #T_6fbff_row7_col11, #T_6fbff_row7_col14, #T_6fbff_row7_col15, #T_6fbff_row7_col17, #T_6fbff_row7_col18, #T_6fbff_row7_col19, #T_6fbff_row7_col21, #T_6fbff_row7_col22, #T_6fbff_row7_col23, #T_6fbff_row8_col4, #T_6fbff_row8_col5, #T_6fbff_row8_col7, #T_6fbff_row8_col8, #T_6fbff_row8_col9, #T_6fbff_row8_col10, #T_6fbff_row8_col11, #T_6fbff_row8_col14, #T_6fbff_row8_col15, #T_6fbff_row8_col17, #T_6fbff_row8_col18, #T_6fbff_row8_col19, #T_6fbff_row8_col21, #T_6fbff_row8_col22, #T_6fbff_row8_col23, #T_6fbff_row9_col4, #T_6fbff_row9_col5, #T_6fbff_row9_col7, #T_6fbff_row9_col8, #T_6fbff_row9_col9, #T_6fbff_row9_col10, #T_6fbff_row9_col11, #T_6fbff_row9_col14, #T_6fbff_row9_col15, #T_6fbff_row9_col17, #T_6fbff_row9_col18, #T_6fbff_row9_col19, #T_6fbff_row9_col21, #T_6fbff_row9_col22, #T_6fbff_row9_col23 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# </style>
# <table id="T_6fbff">
#   <caption>Table 2.1: Worst Hygiene Establishments</caption>
#   <thead>
#     <tr>
#       <th id="T_6fbff_level0_col4" class="col_heading level0 col4" >BusinessName</th>
#       <th id="T_6fbff_level0_col5" class="col_heading level0 col5" >BusinessType</th>
#       <th id="T_6fbff_level0_col7" class="col_heading level0 col7" >AddressLine1</th>
#       <th id="T_6fbff_level0_col8" class="col_heading level0 col8" >AddressLine2</th>
#       <th id="T_6fbff_level0_col9" class="col_heading level0 col9" >AddressLine3</th>
#       <th id="T_6fbff_level0_col10" class="col_heading level0 col10" >AddressLine4</th>
#       <th id="T_6fbff_level0_col11" class="col_heading level0 col11" >PostCode</th>
#       <th id="T_6fbff_level0_col14" class="col_heading level0 col14" >Phone</th>
#       <th id="T_6fbff_level0_col15" class="col_heading level0 col15" >RatingValue</th>
#       <th id="T_6fbff_level0_col17" class="col_heading level0 col17" >RatingDate</th>
#       <th id="T_6fbff_level0_col18" class="col_heading level0 col18" >NewRatingPending</th>
#       <th id="T_6fbff_level0_col19" class="col_heading level0 col19" >scores</th>
#       <th id="T_6fbff_level0_col21" class="col_heading level0 col21" >LocalAuthorityName</th>
#       <th id="T_6fbff_level0_col22" class="col_heading level0 col22" >LocalAuthorityWebSite</th>
#       <th id="T_6fbff_level0_col23" class="col_heading level0 col23" >LocalAuthorityEmailAddress</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_6fbff_row0_col4" class="data row0 col4" >The Chase Rest Home</td>
#       <td id="T_6fbff_row0_col5" class="data row0 col5" >Caring Premises</td>
#       <td id="T_6fbff_row0_col7" class="data row0 col7" >5-6 Southfields Road</td>
#       <td id="T_6fbff_row0_col8" class="data row0 col8" >Eastbourne</td>
#       <td id="T_6fbff_row0_col9" class="data row0 col9" >East Sussex</td>
#       <td id="T_6fbff_row0_col10" class="data row0 col10" ></td>
#       <td id="T_6fbff_row0_col11" class="data row0 col11" >BN21 1BU</td>
#       <td id="T_6fbff_row0_col14" class="data row0 col14" ></td>
#       <td id="T_6fbff_row0_col15" class="data row0 col15" >nan</td>
#       <td id="T_6fbff_row0_col17" class="data row0 col17" >2021-09-23</td>
#       <td id="T_6fbff_row0_col18" class="data row0 col18" >False</td>
#       <td id="T_6fbff_row0_col19" class="data row0 col19" >{'Hygiene': 20, 'Structural': 20, 'ConfidenceInManagement': 20}</td>
#       <td id="T_6fbff_row0_col21" class="data row0 col21" >Eastbourne</td>
#       <td id="T_6fbff_row0_col22" class="data row0 col22" >http://www.eastbourne.gov.uk/foodratings</td>
#       <td id="T_6fbff_row0_col23" class="data row0 col23" >Customerfirst@eastbourne.gov.uk</td>
#     </tr>
#     <tr>
#       <td id="T_6fbff_row1_col4" class="data row1 col4" >Brenalwood</td>
#       <td id="T_6fbff_row1_col5" class="data row1 col5" >Caring Premises</td>
#       <td id="T_6fbff_row1_col7" class="data row1 col7" >Hall Lane</td>
#       <td id="T_6fbff_row1_col8" class="data row1 col8" >Walton-on-the-Naze</td>
#       <td id="T_6fbff_row1_col9" class="data row1 col9" >Essex</td>
#       <td id="T_6fbff_row1_col10" class="data row1 col10" ></td>
#       <td id="T_6fbff_row1_col11" class="data row1 col11" >CO14 8HN</td>
#       <td id="T_6fbff_row1_col14" class="data row1 col14" ></td>
#       <td id="T_6fbff_row1_col15" class="data row1 col15" >nan</td>
#       <td id="T_6fbff_row1_col17" class="data row1 col17" >2022-06-22</td>
#       <td id="T_6fbff_row1_col18" class="data row1 col18" >False</td>
#       <td id="T_6fbff_row1_col19" class="data row1 col19" >{'Hygiene': 20, 'Structural': 15, 'ConfidenceInManagement': 30}</td>
#       <td id="T_6fbff_row1_col21" class="data row1 col21" >Tendring</td>
#       <td id="T_6fbff_row1_col22" class="data row1 col22" >http://www.tendringdc.gov.uk/</td>
#       <td id="T_6fbff_row1_col23" class="data row1 col23" >fhsadmin@tendringdc.gov.uk</td>
#     </tr>
#     <tr>
#       <td id="T_6fbff_row2_col4" class="data row2 col4" >Melrose Hotel</td>
#       <td id="T_6fbff_row2_col5" class="data row2 col5" >Hotel/bed & breakfast/guest house</td>
#       <td id="T_6fbff_row2_col7" class="data row2 col7" >53 Marine Parade East</td>
#       <td id="T_6fbff_row2_col8" class="data row2 col8" >Clacton On Sea</td>
#       <td id="T_6fbff_row2_col9" class="data row2 col9" >Essex</td>
#       <td id="T_6fbff_row2_col10" class="data row2 col10" ></td>
#       <td id="T_6fbff_row2_col11" class="data row2 col11" >CO15 6AD</td>
#       <td id="T_6fbff_row2_col14" class="data row2 col14" ></td>
#       <td id="T_6fbff_row2_col15" class="data row2 col15" >nan</td>
#       <td id="T_6fbff_row2_col17" class="data row2 col17" >2021-08-13</td>
#       <td id="T_6fbff_row2_col18" class="data row2 col18" >False</td>

# %% [markdown]
# ### **Display Worst Hygiene Establishments' Locations**

# %%
hoverColumnsListOfStrings \
    = ['BusinessName',
       'Hygiene'
       'BusinessType'
       'AddressLine1', 
       'AddressLine2', 
       'AddressLine3'
       'PostCode',
       'LocalAuthorityName']

function \
    .DisplayHVPlotFromDataFrame \
        (worstHygieneLocationsDataFrame,
         'Figure 2.1.1: Worst Hygiene Establishments',
         'BusinessName',
         'MarkerSize',
         (-1.0, 1.5),
         (50.7, 52.2),
         0.7,
         'OSM',
         hoverColumnsListOfStrings)
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Longitude,Latitude]   (BusinessName,MarkerSize,AddressLine2,LocalAuthorityName)

# %%
function \
    .DisplayHVPlotFromDataFrame \
        (worstHygieneLocationsDataFrame,
         'Figure 2.1.2: Worst Hygiene Establishments\n(Close-Up)',
         'BusinessName',
         'MarkerSize',
         (-0.05, 0.2),
         (51.45, 51.6),
         0.7,
         'OSM',
         hoverColumnsListOfStrings)
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Longitude,Latitude]   (BusinessName,MarkerSize,AddressLine2,LocalAuthorityName)

# %% [markdown]
# ## **2.2 -- Which establishments in London have a high rating value greater than or equal to 4 (1-5)?**

# %% [markdown]
# ### **Number of Establishments from `count_documents`**

# %%
# These lines of code query and display the number of establishments 
# in London where the 'RatingValue' field has a value greater than
# or equal to 4.
queryDictionary \
    = {'LocalAuthorityName': 
           {'$regex': 'London'}, 
            'RatingValue': {'$gte':4}}

numberOfEstablishmentsInteger \
    = currentPyMongoCollectionObject \
        .count_documents \
            (queryDictionary)

log_subroutine \
    .PrintAndLogWriteText \
        ('\033[1m' \
         + 'There are {:,} establishments with a rating value greater than ' \
             .format \
                (numberOfEstablishmentsInteger) \
         + 'or equal to 4.' \
         + '\033[0m')
# Out:
# There are 33 establishments with a rating value greater than or equal to 4.

# %% [markdown]
# ### **Display First Document**

# %%
# This query returns all the documents where the establishment
# is in London and the 'RatingValue' field has a value greater 
# than or equal to 4.
queryResultsDictionaryList \
    = currentPyMongoCollectionObject \
        .find \
            (queryDictionary)


# This line of code displays the first document from the query 
# results.
pprint \
    (queryResultsDictionaryList[0])
# Out:
# {'AddressLine1': 'Oak Apple Farm Building 103 Sheernes Docks',
#  'AddressLine2': 'Sheppy Kent',
#  'AddressLine3': '',
#  'AddressLine4': '',
#  'BusinessName': "Charlie's",
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4627.439467780196,
#  'FHRSID': 621707,
#  'LocalAuthorityBusinessID': 'PI/000025307',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'ME12',
#  'RatingDate': '2021-10-18',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingValue': 4,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('654b006a8942454b196805d3'),
#  'geocode': {'latitude': 51.369321, 'longitude': 0.508551},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/621707',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 10}}

# %% [markdown]
# ### **High Rating Value, London Establishments Data Set**

# %%
# This line of code creates the DataFrame.
highRatingLondonDataFrame \
    = pd.DataFrame \
        (list \
            (queryResultsDictionaryList))

# This function rearranges the columns in the DataFrame.
highRatingLondonDataFrame \
    = local_function \
        .ReturnReorderedColumnsNoSQLDataFrame \
            (highRatingLondonDataFrame)


log_function \
    .DebugReturnObjectWriteObject \
        (highRatingLondonDataFrame)

# %% [markdown]
# ### **Number of Rows in High Rating Value, London Data Set**

# %%
log_subroutine \
    .PrintAndLogWriteText \
        ('\033[1m' \
         + 'The number of rows in the High Rating Value, London DataFrame is {:,}.' \
            .format \
                (len \
                     (highRatingLondonDataFrame)) \
         + '\033[0m')
# Out:
# The number of rows in the High Rating Value, London DataFrame is 33.

# %% [markdown]
# ### **High Rating Value, London Establishments' Locations Data Set**

# %%
highRatingLondonLocationsDataFrame \
    = local_function \
        .ReturnLocationsDataFrame \
            (highRatingLondonDataFrame,
             'RatingValue', 50)


log_function \
    .DebugReturnObjectWriteObject \
        (highRatingLondonLocationsDataFrame)

# %% [markdown]
# ### **Display High Rating Value, London Establishments**

# %%
# This line of code displays a formatted DataFrame hiding those columns 
# that are not necessary for editorial decisions.
captionString \
    = 'Table 2.2: High Rating Value, London Establishments'

currentStylerObject \
    = function \
        .ReturnStylerObjectStandardFormat \
            (highRatingLondonDataFrame.head(10),
             captionString,
             hideFlagBooleanParameter = True) \
                .format({'RatingValue': '{:,.0f}'}) \
                .hide \
                    (['_id',
                      'ChangesByServerID',
                      'FHRSID',
                      'LocalAuthorityBusinessID',
                      'BusinessTypeID',
                      'geocode',
                      'Distance',
                      'RatingKey',
                      'RightToReply',
                      'SchemeType',
                      'LocalAuthorityCode',
                      'meta',
                      'links'], 
                     axis = 1)

log_function \
    .ReturnStylerObjectSavePNGImage \
        (currentStylerObject,
         captionString)
# Out:
# <style type="text/css">
# #T_7b161 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_7b161_row0_col4, #T_7b161_row0_col5, #T_7b161_row0_col7, #T_7b161_row0_col8, #T_7b161_row0_col9, #T_7b161_row0_col10, #T_7b161_row0_col11, #T_7b161_row0_col14, #T_7b161_row0_col15, #T_7b161_row0_col17, #T_7b161_row0_col18, #T_7b161_row0_col19, #T_7b161_row0_col21, #T_7b161_row0_col22, #T_7b161_row0_col23, #T_7b161_row1_col4, #T_7b161_row1_col5, #T_7b161_row1_col7, #T_7b161_row1_col8, #T_7b161_row1_col9, #T_7b161_row1_col10, #T_7b161_row1_col11, #T_7b161_row1_col14, #T_7b161_row1_col15, #T_7b161_row1_col17, #T_7b161_row1_col18, #T_7b161_row1_col19, #T_7b161_row1_col21, #T_7b161_row1_col22, #T_7b161_row1_col23, #T_7b161_row2_col4, #T_7b161_row2_col5, #T_7b161_row2_col7, #T_7b161_row2_col8, #T_7b161_row2_col9, #T_7b161_row2_col10, #T_7b161_row2_col11, #T_7b161_row2_col14, #T_7b161_row2_col15, #T_7b161_row2_col17, #T_7b161_row2_col18, #T_7b161_row2_col19, #T_7b161_row2_col21, #T_7b161_row2_col22, #T_7b161_row2_col23, #T_7b161_row3_col4, #T_7b161_row3_col5, #T_7b161_row3_col7, #T_7b161_row3_col8, #T_7b161_row3_col9, #T_7b161_row3_col10, #T_7b161_row3_col11, #T_7b161_row3_col14, #T_7b161_row3_col15, #T_7b161_row3_col17, #T_7b161_row3_col18, #T_7b161_row3_col19, #T_7b161_row3_col21, #T_7b161_row3_col22, #T_7b161_row3_col23, #T_7b161_row4_col4, #T_7b161_row4_col5, #T_7b161_row4_col7, #T_7b161_row4_col8, #T_7b161_row4_col9, #T_7b161_row4_col10, #T_7b161_row4_col11, #T_7b161_row4_col14, #T_7b161_row4_col15, #T_7b161_row4_col17, #T_7b161_row4_col18, #T_7b161_row4_col19, #T_7b161_row4_col21, #T_7b161_row4_col22, #T_7b161_row4_col23, #T_7b161_row5_col4, #T_7b161_row5_col5, #T_7b161_row5_col7, #T_7b161_row5_col8, #T_7b161_row5_col9, #T_7b161_row5_col10, #T_7b161_row5_col11, #T_7b161_row5_col14, #T_7b161_row5_col15, #T_7b161_row5_col17, #T_7b161_row5_col18, #T_7b161_row5_col19, #T_7b161_row5_col21, #T_7b161_row5_col22, #T_7b161_row5_col23, #T_7b161_row6_col4, #T_7b161_row6_col5, #T_7b161_row6_col7, #T_7b161_row6_col8, #T_7b161_row6_col9, #T_7b161_row6_col10, #T_7b161_row6_col11, #T_7b161_row6_col14, #T_7b161_row6_col15, #T_7b161_row6_col17, #T_7b161_row6_col18, #T_7b161_row6_col19, #T_7b161_row6_col21, #T_7b161_row6_col22, #T_7b161_row6_col23, #T_7b161_row7_col4, #T_7b161_row7_col5, #T_7b161_row7_col7, #T_7b161_row7_col8, #T_7b161_row7_col9, #T_7b161_row7_col10, #T_7b161_row7_col11, #T_7b161_row7_col14, #T_7b161_row7_col15, #T_7b161_row7_col17, #T_7b161_row7_col18, #T_7b161_row7_col19, #T_7b161_row7_col21, #T_7b161_row7_col22, #T_7b161_row7_col23, #T_7b161_row8_col4, #T_7b161_row8_col5, #T_7b161_row8_col7, #T_7b161_row8_col8, #T_7b161_row8_col9, #T_7b161_row8_col10, #T_7b161_row8_col11, #T_7b161_row8_col14, #T_7b161_row8_col15, #T_7b161_row8_col17, #T_7b161_row8_col18, #T_7b161_row8_col19, #T_7b161_row8_col21, #T_7b161_row8_col22, #T_7b161_row8_col23, #T_7b161_row9_col4, #T_7b161_row9_col5, #T_7b161_row9_col7, #T_7b161_row9_col8, #T_7b161_row9_col9, #T_7b161_row9_col10, #T_7b161_row9_col11, #T_7b161_row9_col14, #T_7b161_row9_col15, #T_7b161_row9_col17, #T_7b161_row9_col18, #T_7b161_row9_col19, #T_7b161_row9_col21, #T_7b161_row9_col22, #T_7b161_row9_col23 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# </style>
# <table id="T_7b161">
#   <caption>Table 2.2: High Rating Value, London Establishments</caption>
#   <thead>
#     <tr>
#       <th id="T_7b161_level0_col4" class="col_heading level0 col4" >BusinessName</th>
#       <th id="T_7b161_level0_col5" class="col_heading level0 col5" >BusinessType</th>
#       <th id="T_7b161_level0_col7" class="col_heading level0 col7" >AddressLine1</th>
#       <th id="T_7b161_level0_col8" class="col_heading level0 col8" >AddressLine2</th>
#       <th id="T_7b161_level0_col9" class="col_heading level0 col9" >AddressLine3</th>
#       <th id="T_7b161_level0_col10" class="col_heading level0 col10" >AddressLine4</th>
#       <th id="T_7b161_level0_col11" class="col_heading level0 col11" >PostCode</th>
#       <th id="T_7b161_level0_col14" class="col_heading level0 col14" >Phone</th>
#       <th id="T_7b161_level0_col15" class="col_heading level0 col15" >RatingValue</th>
#       <th id="T_7b161_level0_col17" class="col_heading level0 col17" >RatingDate</th>
#       <th id="T_7b161_level0_col18" class="col_heading level0 col18" >NewRatingPending</th>
#       <th id="T_7b161_level0_col19" class="col_heading level0 col19" >scores</th>
#       <th id="T_7b161_level0_col21" class="col_heading level0 col21" >LocalAuthorityName</th>
#       <th id="T_7b161_level0_col22" class="col_heading level0 col22" >LocalAuthorityWebSite</th>
#       <th id="T_7b161_level0_col23" class="col_heading level0 col23" >LocalAuthorityEmailAddress</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_7b161_row0_col4" class="data row0 col4" >Charlie's</td>
#       <td id="T_7b161_row0_col5" class="data row0 col5" >Other catering premises</td>
#       <td id="T_7b161_row0_col7" class="data row0 col7" >Oak Apple Farm Building 103 Sheernes Docks</td>
#       <td id="T_7b161_row0_col8" class="data row0 col8" >Sheppy Kent</td>
#       <td id="T_7b161_row0_col9" class="data row0 col9" ></td>
#       <td id="T_7b161_row0_col10" class="data row0 col10" ></td>
#       <td id="T_7b161_row0_col11" class="data row0 col11" >ME12</td>
#       <td id="T_7b161_row0_col14" class="data row0 col14" ></td>
#       <td id="T_7b161_row0_col15" class="data row0 col15" >4</td>
#       <td id="T_7b161_row0_col17" class="data row0 col17" >2021-10-18</td>
#       <td id="T_7b161_row0_col18" class="data row0 col18" >False</td>
#       <td id="T_7b161_row0_col19" class="data row0 col19" >{'Hygiene': 5, 'Structural': 10, 'ConfidenceInManagement': 5}</td>
#       <td id="T_7b161_row0_col21" class="data row0 col21" >City of London Corporation</td>
#       <td id="T_7b161_row0_col22" class="data row0 col22" >http://www.cityoflondon.gov.uk/Corporation/homepage.htm</td>
#       <td id="T_7b161_row0_col23" class="data row0 col23" >publicprotection@cityoflondon.gov.uk</td>
#     </tr>
#     <tr>
#       <td id="T_7b161_row1_col4" class="data row1 col4" >Mv City Cruises Erasmus</td>
#       <td id="T_7b161_row1_col5" class="data row1 col5" >Other catering premises</td>
#       <td id="T_7b161_row1_col7" class="data row1 col7" >Cherry Garden Pier</td>
#       <td id="T_7b161_row1_col8" class="data row1 col8" >Cherry Garden Street Rotherhithe</td>
#       <td id="T_7b161_row1_col9" class="data row1 col9" >Charlton</td>
#       <td id="T_7b161_row1_col10" class="data row1 col10" ></td>
#       <td id="T_7b161_row1_col11" class="data row1 col11" >TN4 8HR</td>
#       <td id="T_7b161_row1_col14" class="data row1 col14" ></td>
#       <td id="T_7b161_row1_col15" class="data row1 col15" >5</td>
#       <td id="T_7b161_row1_col17" class="data row1 col17" >2021-05-14</td>
#       <td id="T_7b161_row1_col18" class="data row1 col18" >False</td>
#       <td id="T_7b161_row1_col19" class="data row1 col19" >{'Hygiene': 0, 'Structural': 5, 'ConfidenceInManagement': 0}</td>
#       <td id="T_7b161_row1_col21" class="data row1 col21" >City of London Corporation</td>
#       <td id="T_7b161_row1_col22" class="data row1 col22" >http://www.cityoflondon.gov.uk/Corporation/homepage.htm</td>
#       <td id="T_7b161_row1_col23" class="data row1 col23" >publicprotection@cityoflondon.gov.uk</td>
#     </tr>
#     <tr>
#       <td id="T_7b161_row2_col4" class="data row2 col4" >Benfleet Motor Yacht Club</td>
#       <td id="T_7b161_row2_col5" class="data row2 col5" >Other catering premises</td>
#       <td id="T_7b161_row2_col7" class="data row2 col7" >Ferry Road</td>
#       <td id="T_7b161_row2_col8" class="data row2 col8" >South Benfleet Essex</td>
#       <td id="T_7b161_row2_col9" class="data row2 col9" ></td>
#       <td id="T_7b161_row2_col10" class="data row2 col10" ></td>
#       <td id="T_7b161_row2_col11" class="data row2 col11" >SS7 1NF</td>
#       <td id="T_7b161_row2_col14" class="data row2 col14" ></td>
#       <td id="T_7b161_row2_col15" class="data row2 col15" >4</td>
#       <td

# %% [markdown]
# ### **Display High Rating Value, London Establishments' Locations**

# %%
function \
    .DisplayHVPlotFromDataFrame \
        (highRatingLondonLocationsDataFrame,
         'Figure 2.2.1: High Rating Value, London',
         'BusinessName',
         'MarkerSize',
         (-1, 1.5),
         (50.7, 52.2),
         0.7,
         'OSM',
         hoverColumnsListOfStrings)
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Longitude,Latitude]   (BusinessName,MarkerSize,AddressLine2,LocalAuthorityName)

# %%
function \
    .DisplayHVPlotFromDataFrame \
        (highRatingLondonLocationsDataFrame,
         'Figure 2.2.2: High Rating Value, London (Close-Up)',
         'BusinessName',
         'MarkerSize',
         (0.0, 0.1),
         (51.49, 51.54),
         0.7,
         'OSM',
         hoverColumnsListOfStrings)
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Longitude,Latitude]   (BusinessName,MarkerSize,AddressLine2,LocalAuthorityName)

# %% [markdown]
# ## **2.3 -- What are the top 5 establishments with a rating value of 5, sorted by best hygiene score, nearest to the new restaurant added, "Penang Flavours?**

# %% [markdown]
# ### **Penang Flavours' Latitude and Longitude**

# %%
# This line of code retrieves the Penang Flavours's document fields, 
# 'latitude' and 'longitude'.
penangFlavoursCoordinatesDictionary \
    = currentPyMongoCollectionObject \
        .find_one \
            ({'BusinessName':'Penang Flavours'}, 
             ['geocode.longitude', 
              'geocode.latitude'])


# This line of code extracts the Penang Flavours's 'latitude' field value.
latitudeFloat \
    = penangFlavoursCoordinatesDictionary \
        ['geocode'] \
        ['latitude']


# This line of code extracts the Penang Flavours's 'longitude' field value.
longitudeFloat \
    = penangFlavoursCoordinatesDictionary \
        ['geocode'] \
        ['longitude']

# %% [markdown]
# ### **Query Search Range Variables**

# %%
# This line of code establishes the search range as ±0.01 degrees.
degreeSearchFloat = 0.01


# These lines of code calculate and assign the minimum and maximum latitude.
minimumLatitudeFloat \
    = latitudeFloat - degreeSearchFloat

maximumLatitudeFloat \
    = latitudeFloat + degreeSearchFloat


# These lines of code calculate and assign the minimum and maximum longitude.
minimumLongitudeFloat \
    = longitudeFloat - degreeSearchFloat

maximumLongitudeFloat \
    = longitudeFloat + degreeSearchFloat

# %% [markdown]
# ### **Query Results**

# %%
# These Dictionaries are the query parameters.
queryDictionary \
    = {'RatingValue': 5,
       'geocode.latitude': \
           {'$gte': minimumLatitudeFloat, '$lte': maximumLatitudeFloat},
       'geocode.longitude': \
           {'$gte': minimumLongitudeFloat, '$lte': maximumLongitudeFloat}}
       
sortValuesTupleList \
    = [('scores.Hygiene', 1)]
       
limitInteger = 5


# This query returns the top 5 establishments with a 'RatingValue' field
# value of 5, sorted by lowest hygiene score, nearest to the restaurant,
# 'Penang Flavours'.
resultsPyMongoCursorList \
    = list \
        (currentPyMongoCollectionObject \
            .find \
                (queryDictionary) \
            .sort \
                 (sortValuesTupleList) \
            .limit \
                 (limitInteger))


log_function \
    .DebugReturnObjectWriteObject \
        (resultsPyMongoCursorList)

# %% [markdown]
# ### **Number of Establishments from `count_documents`**

# %%
numberOfEstablishmentsInteger \
    = currentPyMongoCollectionObject \
        .count_documents \
            (queryDictionary, 
             limit \
                 = limitInteger)

log_subroutine \
    .PrintAndLogWriteText \
        ('\033[1m' \
         + 'Due to the query parameter limiting the number of results, ' \
         + 'there are {:,} establishments with a rating value of 5.' \
            .format \
                (numberOfEstablishmentsInteger) \
         + '\033[0m')
# Out:
# Due to the query parameter limiting the number of results, there are 5 establishments with a rating value of 5.

# %% [markdown]
# ### **Display All Documents**

# %%
pprint \
    (resultsPyMongoCursorList)
# Out:
# [{'AddressLine1': 'Restaurant And Premises 107A Plumstead High Street',
#   'AddressLine2': '',
#   'AddressLine3': 'Plumstead',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Howe and Co Fish and Chips - Van 17',
#   'BusinessType': 'Mobile caterer',
#   'BusinessTypeID': 7846,
#   'ChangesByServerID': 0,
#   'Distance': 4646.95593107927,
#   'FHRSID': 1380578,
#   'LocalAuthorityBusinessID': '14425',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 1SE',
#   'RatingDate': '2021-11-11',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('654b006a8942454b196843fa'),
#   'geocode': {'latitude': 51.4875335693359, 'longitude': 0.0925370007753372},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1380578',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}},
#  {'AddressLine1': '35 Lakedale Road',
#   'AddressLine2': '',
#   'AddressLine3': 'Plumstead',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Atlantic Fish Bar',
#   'BusinessType': 'Takeaway/sandwich shop',
#   'BusinessTypeID': 7844,
#   'ChangesByServerID': 0,
#   'Distance': 4646.974611855838,
#   'FHRSID': 694478,
#   'LocalAuthorityBusinessID': 'PI/000086506',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 1PR',
#   'RatingDate': '2021-06-16',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('654b006a8942454b19684432'),
#   'geocode': {'latitude': 51.4867296, 'longitude': 0.0912164},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/694478',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 0}},
#  {'AddressLine1': 'Plumstead Manor School Old Mill Road',
#   'AddressLine2': '',
#   'AddressLine3': 'Plumstead',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Plumstead Manor Nursery',
#   'BusinessType': 'Caring Premises',
#   'BusinessTypeID': 5,
#   'ChangesByServerID': 0,
#   'Distance': 4646.9740101340385,
#   'FHRSID': 695241,
#   'LocalAuthorityBusinessID': 'PI/000179088',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 1QG',
#   'RatingDate': '2021-06-16',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('654b006a8942454b1968442f'),
#   'geocode': {'latitude': 51.481517791748, 'longitude': 0.0859939977526665},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/695241',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 0}},
#  {'AddressLine1': '144 - 146 Plumstead High Street',
#   'AddressLine2': '',
#   'AddressLine3': 'Plumstead',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Iceland',
#   'BusinessType': 'Retailers - supermarkets/hypermarkets',
#   'BusinessTypeID': 7840,
#   'ChangesByServerID': 0,
#   'Distance': 4646.946071297699,
#   'FHRSID': 695223,
#   'LocalAuthorityBusinessID': 'PI/000178842',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 1JQ',
#   'RatingDate': '2019-11-13',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('654b006a8942454b196843ea'),
#   'geocode': {'latitude': 51.4871482849121, 'longitude': 0.0924199968576431},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/695223',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 5}},
#  {'AddressLine1': '130 - 132 Plumstead High Street',
#   'AddressLine2': '',
#   'AddressLine3': 'Plumstead',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Volunteer',
#   'BusinessType': 'Pub/bar/nightclub',
#   'BusinessTypeID': 7843,
#   'ChangesByServerID': 0,
#   'Distance': 4646.965634598608,
#   'FHRSID': 694609,
#   'LocalAuthorityBusinessID': 'PI/000116619',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 1JQ',
#   'RatingDate': '2019-08-05',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('654b006a8942454b19684417'),
#   'geocode': {'latitude': 51.4873437, 'longitude': 0.09208},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/694609',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}]

# %% [markdown]
# ### Highest Rating, Best Hygiene Establishments Data Set**

# %%
# This line of code creates the DataFrame.
highRatingBestHygieneDataFrame \
    = pd.DataFrame \
        (resultsPyMongoCursorList)

# This function rearranges the columns in the DataFrame.
highRatingBestHygieneDataFrame \
    = local_function \
        .ReturnReorderedColumnsNoSQLDataFrame \
            (highRatingBestHygieneDataFrame)


log_function \
    .DebugReturnObjectWriteObject \
        (highRatingBestHygieneDataFrame)

# %% [markdown]
# ### **Number of Rows in Highest Rating, Best Hygiene Establishments Data Set**

# %%
log_subroutine \
    .PrintAndLogWriteText \
        ('\033[1m' \
         + 'The number of rows in the Highest Rating, Best Hygiene DataFrame is {:,}.' \
            .format \
                (len \
                     (highRatingBestHygieneDataFrame)) \
         + '\033[0m')
# Out:
# The number of rows in the Highest Rating, Best Hygiene DataFrame is 5.

# %% [markdown]
# ### **Highest Rating, Best Hygiene Establishments' Locations Data Set**

# %%
highRatingLondonLocationsDataFrame \
    = local_function \
        .ReturnLocationsDataFrame \
            (highRatingBestHygieneDataFrame, 
             'RatingValue', 50)


log_function \
    .DebugReturnObjectWriteObject \
        (highRatingLondonLocationsDataFrame)

# %% [markdown]
# ### **Display Highest Rating, Best Hygiene Establishments**

# %%
# This line of code displays a formatted DataFrame hiding those columns 
# that are not necessary for editorial decisions.
captionString \
    = 'Table 2.3: Highest Rating, Best Hygiene Establishments'

currentStylerObject \
    = function \
        .ReturnStylerObjectStandardFormat \
            (highRatingBestHygieneDataFrame,
             captionString,
             hideFlagBooleanParameter = True) \
                .format({'RatingValue': '{:,.0f}'}) \
                .hide \
                    (['_id',
                      'ChangesByServerID',
                      'FHRSID',
                      'LocalAuthorityBusinessID',
                      'BusinessTypeID',
                      'geocode',
                      'Distance',
                      'RatingKey',
                      'RightToReply',
                      'SchemeType',
                      'LocalAuthorityCode',
                      'meta',
                      'links'], 
                     axis = 1)

log_function \
    .ReturnStylerObjectSavePNGImage \
        (currentStylerObject,
         captionString)
# Out:
# <style type="text/css">
# #T_1939a caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_1939a_row0_col4, #T_1939a_row0_col5, #T_1939a_row0_col7, #T_1939a_row0_col8, #T_1939a_row0_col9, #T_1939a_row0_col10, #T_1939a_row0_col11, #T_1939a_row0_col14, #T_1939a_row0_col15, #T_1939a_row0_col17, #T_1939a_row0_col18, #T_1939a_row0_col19, #T_1939a_row0_col21, #T_1939a_row0_col22, #T_1939a_row0_col23, #T_1939a_row1_col4, #T_1939a_row1_col5, #T_1939a_row1_col7, #T_1939a_row1_col8, #T_1939a_row1_col9, #T_1939a_row1_col10, #T_1939a_row1_col11, #T_1939a_row1_col14, #T_1939a_row1_col15, #T_1939a_row1_col17, #T_1939a_row1_col18, #T_1939a_row1_col19, #T_1939a_row1_col21, #T_1939a_row1_col22, #T_1939a_row1_col23, #T_1939a_row2_col4, #T_1939a_row2_col5, #T_1939a_row2_col7, #T_1939a_row2_col8, #T_1939a_row2_col9, #T_1939a_row2_col10, #T_1939a_row2_col11, #T_1939a_row2_col14, #T_1939a_row2_col15, #T_1939a_row2_col17, #T_1939a_row2_col18, #T_1939a_row2_col19, #T_1939a_row2_col21, #T_1939a_row2_col22, #T_1939a_row2_col23, #T_1939a_row3_col4, #T_1939a_row3_col5, #T_1939a_row3_col7, #T_1939a_row3_col8, #T_1939a_row3_col9, #T_1939a_row3_col10, #T_1939a_row3_col11, #T_1939a_row3_col14, #T_1939a_row3_col15, #T_1939a_row3_col17, #T_1939a_row3_col18, #T_1939a_row3_col19, #T_1939a_row3_col21, #T_1939a_row3_col22, #T_1939a_row3_col23, #T_1939a_row4_col4, #T_1939a_row4_col5, #T_1939a_row4_col7, #T_1939a_row4_col8, #T_1939a_row4_col9, #T_1939a_row4_col10, #T_1939a_row4_col11, #T_1939a_row4_col14, #T_1939a_row4_col15, #T_1939a_row4_col17, #T_1939a_row4_col18, #T_1939a_row4_col19, #T_1939a_row4_col21, #T_1939a_row4_col22, #T_1939a_row4_col23 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# </style>
# <table id="T_1939a">
#   <caption>Table 2.3: Highest Rating, Best Hygiene Establishments</caption>
#   <thead>
#     <tr>
#       <th id="T_1939a_level0_col4" class="col_heading level0 col4" >BusinessName</th>
#       <th id="T_1939a_level0_col5" class="col_heading level0 col5" >BusinessType</th>
#       <th id="T_1939a_level0_col7" class="col_heading level0 col7" >AddressLine1</th>
#       <th id="T_1939a_level0_col8" class="col_heading level0 col8" >AddressLine2</th>
#       <th id="T_1939a_level0_col9" class="col_heading level0 col9" >AddressLine3</th>
#       <th id="T_1939a_level0_col10" class="col_heading level0 col10" >AddressLine4</th>
#       <th id="T_1939a_level0_col11" class="col_heading level0 col11" >PostCode</th>
#       <th id="T_1939a_level0_col14" class="col_heading level0 col14" >Phone</th>
#       <th id="T_1939a_level0_col15" class="col_heading level0 col15" >RatingValue</th>
#       <th id="T_1939a_level0_col17" class="col_heading level0 col17" >RatingDate</th>
#       <th id="T_1939a_level0_col18" class="col_heading level0 col18" >NewRatingPending</th>
#       <th id="T_1939a_level0_col19" class="col_heading level0 col19" >scores</th>
#       <th id="T_1939a_level0_col21" class="col_heading level0 col21" >LocalAuthorityName</th>
#       <th id="T_1939a_level0_col22" class="col_heading level0 col22" >LocalAuthorityWebSite</th>
#       <th id="T_1939a_level0_col23" class="col_heading level0 col23" >LocalAuthorityEmailAddress</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_1939a_row0_col4" class="data row0 col4" >Howe and Co Fish and Chips - Van 17</td>
#       <td id="T_1939a_row0_col5" class="data row0 col5" >Mobile caterer</td>
#       <td id="T_1939a_row0_col7" class="data row0 col7" >Restaurant And Premises 107A Plumstead High Street</td>
#       <td id="T_1939a_row0_col8" class="data row0 col8" ></td>
#       <td id="T_1939a_row0_col9" class="data row0 col9" >Plumstead</td>
#       <td id="T_1939a_row0_col10" class="data row0 col10" >Greenwich</td>
#       <td id="T_1939a_row0_col11" class="data row0 col11" >SE18 1SE</td>
#       <td id="T_1939a_row0_col14" class="data row0 col14" ></td>
#       <td id="T_1939a_row0_col15" class="data row0 col15" >5</td>
#       <td id="T_1939a_row0_col17" class="data row0 col17" >2021-11-11</td>
#       <td id="T_1939a_row0_col18" class="data row0 col18" >False</td>
#       <td id="T_1939a_row0_col19" class="data row0 col19" >{'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 0}</td>
#       <td id="T_1939a_row0_col21" class="data row0 col21" >Greenwich</td>
#       <td id="T_1939a_row0_col22" class="data row0 col22" >http://www.royalgreenwich.gov.uk</td>
#       <td id="T_1939a_row0_col23" class="data row0 col23" >health@royalgreenwich.gov.uk</td>
#     </tr>
#     <tr>
#       <td id="T_1939a_row1_col4" class="data row1 col4" >Atlantic Fish Bar</td>
#       <td id="T_1939a_row1_col5" class="data row1 col5" >Takeaway/sandwich shop</td>
#       <td id="T_1939a_row1_col7" class="data row1 col7" >35 Lakedale Road</td>
#       <td id="T_1939a_row1_col8" class="data row1 col8" ></td>
#       <td id="T_1939a_row1_col9" class="data row1 col9" >Plumstead</td>
#       <td id="T_1939a_row1_col10" class="data row1 col10" >Greenwich</td>
#       <td id="T_1939a_row1_col11" class="data row1 col11" >SE18 1PR</td>
#       <td id="T_1939a_row1_col14" class="data row1 col14" ></td>
#       <td id="T_1939a_row1_col15" class="data row1 col15" >5</td>
#       <td id="T_1939a_row1_col17" class="data row1 col17" >2021-06-16</td>
#       <td id="T_1939a_row1_col18" class="data row1 col18" >False</td>
#       <td id="T_1939a_row1_col19" class="data row1 col19" >{'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 5}</td>
#       <td id="T_1939a_row1_col21" class="data row1 col21" >Greenwich</td>
#       <td id="T_1939a_row1_col22" class="data row1 col22" >http://www.royalgreenwich.gov.uk</td>
#       <td id="T_1939a_row1_col23" class="data row1 col23" >health@royalgreenwich.gov.uk</td>
#     </tr>
#     <tr>
#       <td id="T_1939a_row2_col4" class="data row2 col4" >Plumstead Manor Nursery</td>
#       <td id="T_1939a_row2_col5" class="data row2 col5" >Caring Premises</td>
#       <td id="T_1939a_row2_col7" class="data row2 col7" >Plumstead Manor School Old Mill Road</td>
#       <td id="T_1939a_row2_col8" class="data row2 col8" ></td>
#       <td id="T_1939a_row2_col9" class="data row2 col9" >Plumstead</td>
#       <td id="T_1939a_row2_col10" class="data row2 col10" >Greenwich</td>
#       <td id="T_1939a_row2_col11" class="data row2 col11" >SE18 1QG</td>
#       <td id="T_1939a_row2_col14" class="data row2 col14" ></td>
#       <td id="T_1939a_row2_col15" class="data row2 col15" >5</td>
#       <td id="T_1939a_row2_col17" class="data row2 col17" >2021-06-16</td>
#       <td id="T_1939a_row2_col18" class="data row2 col18" >False</td>
#       <td id="T_1939a_row2_col19" class="data row2 col19" >{'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 5}</td>
#       <td id="T_1939a_row2_col21" class="data row2 col21" >Greenwich</td>
#       <td id="T_1939a_row2_col22" class="data row2 col22" >http://www.royalgreenwich.gov.uk</td>
#       <td id="T_1939a_row2_col23" class="data row2 col23" >health@royalgreenwich.gov.uk</td>
#     </tr>
#     <tr>
#       <td id="T_1939a_row3_col4" class="data row3 col4" >Iceland</td>
#       <td id="T_1939a_row3_col5" class="data row3 col5" >Retailers - supermarkets/hypermarkets</td>
#       <td id="T_1939a_row3_col7" class="data row3 col7" >144 - 146 Plumstead High Street</td>
#       <td id="T_1939a_row3_col8" class="data row3 col8" ></td>
#       <td id="T_1939a_row3_col9" class="data row3 col9" >Plumstead</td>
#       <td id="T_1939a_row3_col10" class="data row3 col10" >Greenwich</td>
#       <td id="T_1939a_row3_col11" class="data row3 col11" >SE18 1JQ</td>
#       <td id="T_1939a_row3_col14" class="data row3 col14" ></td>
#       <td id="T_1939a_row3_col15" class="data row3 col15" >5</td>
#       <td id="T_1939a_row3_col17" class="data row3 col17" >2019-11-13</td>
#       <td id="T_1939a_row3_col18" class="data row3 col18" >False</td>
#       <td id="T_1939a_row3_col19" class="data row3 col19" >{'Hygiene': 0, 'Structural': 5, 'ConfidenceInManagement': 5}</td>
#       <td id="T_1939a_row3_col21" class="data row3 col21" >Greenwich</td>
#       <td id="T_1939a_row3_col22" class="data row3 col22" >

# %% [markdown]
# ### **Display Highest Rating, Best Hygiene Establishments' Locations**

# %%
function \
    .DisplayHVPlotFromDataFrame \
        (highRatingLondonLocationsDataFrame,
         'Figure 2.3.2: Highest Rating, Best Hygiene (Close-Up)',
         'BusinessName',
         'MarkerSize',
         (-1, 1.5),
         (50.7, 52.2),
         0.7,
         'OSM',
         hoverColumnsListOfStrings)
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Longitude,Latitude]   (BusinessName,MarkerSize,AddressLine2,LocalAuthorityName)

# %%
function \
    .DisplayHVPlotFromDataFrame \
        (highRatingLondonLocationsDataFrame,
         'Figure 2.3.2: Highest Rating, Best Hygiene (Close-Up)',
         'BusinessName',
         'MarkerSize',
         (0.08, 0.10),
         (51.48, 51.49),
         0.7,
         'OSM',
         hoverColumnsListOfStrings)
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Longitude,Latitude]   (BusinessName,MarkerSize,AddressLine2,LocalAuthorityName)

# %% [markdown]
# ## **2.4 -- How many establishments in each Local Authority area have a hygiene score of 0 (the best possible rating)? Sort the number of establishments from highest to lowest, and print out the top ten local authority areas.**

# %% [markdown]
# ### **Aggregation Query Parameters**

# %%
# 1. This Dictionary matches establishments with a hygiene score of 0.
matchQueryDictionary \
    = {'$match': {'scores.Hygiene': 0}}

# 2. This Dictionary groups the matches by Local Authority and counts 
# how many establishments meet the match criteria for each Local Authority.
groupQueryDictionary \
    = {'$group': \
           {'_id': '$LocalAuthorityName', 
            'count': {'$sum': 1}}}

# 3. This Dictionary sorts the matches in descending order 
# (from highest to lowest) based on count.
sortValuesDictionary \
    = {'$sort': {'count': -1}}

pipeLineList \
    = [matchQueryDictionary, 
       groupQueryDictionary, 
       sortValuesDictionary]

# %% [markdown]
# ### **Aggregation Query Results**

# %%
resultsPyMongoCommandCursorList \
    = list \
        (currentPyMongoCollectionObject \
             .aggregate \
                 (pipeLineList))


log_function \
    .DebugReturnObjectWriteObject \
        (resultsPyMongoCommandCursorList)

# %% [markdown]
# ### **Number of Authorities and Establishments from Aggregation Query Results**

# %%
numberOfAuthoritiesInteger \
    = len \
        ([element for element in resultsPyMongoCommandCursorList \
          if isinstance(element, dict)])

numberOfEstablishmentsInteger \
    = sum \
        ([element['count'] for element in resultsPyMongoCommandCursorList \
          if isinstance(element, dict)])

log_subroutine \
    .PrintAndLogWriteText \
        ('\033[1m' \
         + 'From the aggregation query results, there are {:,} ' \
             .format \
                 (numberOfEstablishmentsInteger)
         + 'establishments with a hygiene score of 0 ' \
         + 'in {:,} Local Authorities.' \
                .format \
                    (numberOfAuthoritiesInteger) \
         + '\033[0m')
# Out:
# From the aggregation query results, there are 16,827 establishments with a hygiene score of 0 in 55 Local Authorities.

# %% [markdown]
# ### **Number of Authorities and Establishments from `count_documents`**

# %%
numberOfAuthoritiesInteger \
    = len(currentPyMongoCollectionObject \
            .distinct 
                ('LocalAuthorityName',
                 {'scores.Hygiene': 0}))

numberOfEstablishmentsInteger \
    = currentPyMongoCollectionObject \
        .count_documents \
            ({'scores.Hygiene': 0})

log_subroutine \
    .PrintAndLogWriteText \
        ('\033[1m' \
         + "From the 'count_documents' method, there are {:,} " \
             .format \
                 (numberOfEstablishmentsInteger)
         + 'establishments with a hygiene score of 0 ' \
         + 'in {:,} Local Authorities.' \
                .format \
                    (numberOfAuthoritiesInteger) \
         + '\033[0m')
# Out:
# From the 'count_documents' method, there are 16,827 establishments with a hygiene score of 0 in 55 Local Authorities.

# %% [markdown]
# ### **Display Documents**

# %%
pprint \
    (resultsPyMongoCommandCursorList[0:10])
# Out:
# [{'_id': 'Thanet', 'count': 1130},
#  {'_id': 'Greenwich', 'count': 882},
#  {'_id': 'Maidstone', 'count': 713},
#  {'_id': 'Newham', 'count': 711},
#  {'_id': 'Swale', 'count': 686},
#  {'_id': 'Chelmsford', 'count': 680},
#  {'_id': 'Medway', 'count': 672},
#  {'_id': 'Bexley', 'count': 607},
#  {'_id': 'Southend-On-Sea', 'count': 586},
#  {'_id': 'Tendring', 'count': 542}]

# %% [markdown]
# ### **Highest Hygiene Establishments Data Set**

# %%
highestHygieneScoreDataFrame \
    = pd.DataFrame \
        (resultsPyMongoCommandCursorList)

highestHygieneScoreDataFrame \
    .rename \
        (columns = {'_id': 'LocalAuthorityName',
                    'count': 'Count'},
         inplace = True)


log_function \
    .DebugReturnObjectWriteObject \
        (highestHygieneScoreDataFrame)

# %% [markdown]
# ### **Number of Rows in Highest Hygiene Establishments Data Set**

# %%
log_subroutine \
    .PrintAndLogWriteText \
        ('\033[1m' \
         + 'The number of rows in the Highest Hygiene DataFrame is {:,}.' \
            .format \
                (len \
                     (highestHygieneScoreDataFrame)) \
         + '\033[0m')
# Out:
# The number of rows in the Highest Hygiene DataFrame is 55.

# %% [markdown]
# ### **Display Highest Hygiene Establishments**

# %%
captionString \
    = 'Table 2.4: Local Authorities with Number of Establishments ' \
      + 'with Highest Hygiene Score'

currentStylerObject \
    = function \
        .ReturnStylerObjectStandardFormat \
            (highestHygieneScoreDataFrame.head(10),
             captionString,
             hideFlagBooleanParameter = True) \
                .hide()

log_function \
    .ReturnStylerObjectSavePNGImage \
        (currentStylerObject,
         captionString)
# Out:
# <style type="text/css">
# #T_b16ff caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_b16ff_row0_col0, #T_b16ff_row0_col1, #T_b16ff_row1_col0, #T_b16ff_row1_col1, #T_b16ff_row2_col0, #T_b16ff_row2_col1, #T_b16ff_row3_col0, #T_b16ff_row3_col1, #T_b16ff_row4_col0, #T_b16ff_row4_col1, #T_b16ff_row5_col0, #T_b16ff_row5_col1, #T_b16ff_row6_col0, #T_b16ff_row6_col1, #T_b16ff_row7_col0, #T_b16ff_row7_col1, #T_b16ff_row8_col0, #T_b16ff_row8_col1, #T_b16ff_row9_col0, #T_b16ff_row9_col1 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# </style>
# <table id="T_b16ff">
#   <caption>Table 2.4: Local Authorities with Number of Establishments with Highest Hygiene Score</caption>
#   <thead>
#     <tr>
#       <th id="T_b16ff_level0_col0" class="col_heading level0 col0" >LocalAuthorityName</th>
#       <th id="T_b16ff_level0_col1" class="col_heading level0 col1" >Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_b16ff_row0_col0" class="data row0 col0" >Thanet</td>
#       <td id="T_b16ff_row0_col1" class="data row0 col1" >1,130</td>
#     </tr>
#     <tr>
#       <td id="T_b16ff_row1_col0" class="data row1 col0" >Greenwich</td>
#       <td id="T_b16ff_row1_col1" class="data row1 col1" >882</td>
#     </tr>
#     <tr>
#       <td id="T_b16ff_row2_col0" class="data row2 col0" >Maidstone</td>
#       <td id="T_b16ff_row2_col1" class="data row2 col1" >713</td>
#     </tr>
#     <tr>
#       <td id="T_b16ff_row3_col0" class="data row3 col0" >Newham</td>
#       <td id="T_b16ff_row3_col1" class="data row3 col1" >711</td>
#     </tr>
#     <tr>
#       <td id="T_b16ff_row4_col0" class="data row4 col0" >Swale</td>
#       <td id="T_b16ff_row4_col1" class="data row4 col1" >686</td>
#     </tr>
#     <tr>
#       <td id="T_b16ff_row5_col0" class="data row5 col0" >Chelmsford</td>
#       <td id="T_b16ff_row5_col1" class="data row5 col1" >680</td>
#     </tr>
#     <tr>
#       <td id="T_b16ff_row6_col0" class="data row6 col0" >Medway</td>
#       <td id="T_b16ff_row6_col1" class="data row6 col1" >672</td>
#     </tr>
#     <tr>
#       <td id="T_b16ff_row7_col0" class="data row7 col0" >Bexley</td>
#       <td id="T_b16ff_row7_col1" class="data row7 col1" >607</td>
#     </tr>
#     <tr>
#       <td id="T_b16ff_row8_col0" class="data row8 col0" >Southend-On-Sea</td>
#       <td id="T_b16ff_row8_col1" class="data row8 col1" >586</td>
#     </tr>
#     <tr>
#       <td id="T_b16ff_row9_col0" class="data row9 col0" >Tendring</td>
#       <td id="T_b16ff_row9_col1" class="data row9 col1" >542</td>
#     </tr>
#   </tbody>
# </table>

# %%
#log_subroutine \
#    .EndProgramExecution()
