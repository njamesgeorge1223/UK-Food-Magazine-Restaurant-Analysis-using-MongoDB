# %%
#*******************************************************************************************
 #
 #  File Name:  NoSQLAnalysis.ipynb
 #
 #  File Description:
 #      This interactive Python notebook, NoSQLAnalysis.ipynb, uses the Python module,
 #      PyMongo to analyze restaurant ratings data in a MongoDB database, uk_food, 
 #      for the editors of a food magazine, Eat Safe, Love.
 #
 #
 #  Date            Description                             Programmer
 #  ----------      ------------------------------------    ------------------
 #  09/18/2023      Initial Development                     N. James George
 #
 #******************************************************************************************/

import PyFunctions as function
import PyLogFunctions as log_function
import PyLogSubRoutines as log_subroutine

import pandas as pd

from pprint import pprint
from pymongo import MongoClient
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
CONSTANT_LOCAL_FILE_NAME \
    = 'NoSQLAnalysis.ipynb'


log_subroutine \
    .SetLogMode \
        (False)

log_subroutine \
    .SetDebugMode \
        (False)

log_subroutine \
    .SetImageMode \
        (False)


log_subroutine \
    .BeginProgramExecution \
        ('NoSQLAnalysis')

# %% [markdown]
# # <br> **Section 1: Jupyter Notebook Set Up**

# %% [markdown]
# ## **MongoDB Client**

# %%
# This line of code creates an instance of a MongoDB client and
# assigns it to a variable.
currentPyMongoClientObject \
    = MongoClient \
        (port \
             = 27017)


log_function \
    .DebugReturnObjectWriteObject \
        (currentPyMongoClientObject)

# %% [markdown]
# ## **MongoDB Database Confirmation**

# %%
# These lines of code list all the databases in MongoDB and confirm 
# the existence of the database, uk_food.
log_subroutine \
    .PrintAndLogWriteText \
        ('Here is a List of the current MongoDB Databases:\n'
          + str \
                (currentPyMongoClientObject \
                    .list_database_names()))


if 'uk_food' in currentPyMongoClientObject.list_database_names():
     
    log_subroutine \
        .PrintAndLogWriteText \
            ("\nThe MongoDB Database, 'uk_food', is in the List " \
             + 'of MongoDB Databases.')
    
else:
    
    log_subroutine \
        .PrintAndLogWriteText \
            ("\nThe MongoDB Database, 'uk_food', is NOT in the List. " \
             + 'Please run NoSQLSetup.ipynb before proceeding!')
# Out:
# Here is a List of the current MongoDB Databases:
# ['admin', 'config', 'epa', 'fruits_db', 'local', 'met', 'petsitly_marketing', 'uk_food']
#
# The MongoDB Database, 'uk_food', is in the List of MongoDB Databases.

# %% [markdown]
# ## **MongoDB Database**

# %%
# This line of code creates a PyMongo Database Object for the database, 
# uk_food, and assigns it to a variable.
currentPyMongoDatabaseObject \
    = currentPyMongoClientObject \
        .uk_food
    
    
log_function \
    .DebugReturnObjectWriteObject \
        (str(currentPyMongoDatabaseObject))

# %% [markdown]
# ## **MongoDB Collection Confirmation**

# %%
# These lines of code list all the Collections in the MongoDB database, 
# uk_food, and confirm the existence of the Collection, establishments.
log_subroutine \
    .PrintAndLogWriteText \
        ('Here is a List of the current Collections ' \
         + 'in the MongoDB Database, uk_food:\n' \
         + str \
            (currentPyMongoDatabaseObject \
                .list_collection_names()))


if 'establishments' in currentPyMongoDatabaseObject.list_collection_names():
     
    log_subroutine \
        .PrintAndLogWriteText \
            ("\nThe Collection, 'establishments', " \
             + "is in the MongoDB Database, 'uk_food'.")
    
else:
    
    log_subroutine \
        .PrintAndLogWriteText \
            ("\nThe Collection, 'establishments', " \
             + "is NOT in the MongoDB database, 'uk_food'. " \
             + 'Please run NoSQLSetup.ipynb before proceeding!')
# Out:
# Here is a List of the current Collections in the MongoDB Database, uk_food:
# ['establishments']
#
# The Collection, 'establishments', is in the MongoDB Database, 'uk_food'.

# %% [markdown]
# ## **MongoDB Collection**

# %%
# This line of code creates a PyMongo Collection Object for the collection,
# establishments, and assigns it to a variable.
currentPyMongoCollectionObject \
    = currentPyMongoDatabaseObject \
        .establishments


log_function \
    .DebugReturnObjectWriteObject \
        (str(currentPyMongoCollectionObject))

# %% [markdown]
# # <br> **Section 2: Exploratory Analysis**

# %% [markdown]
# ## **1. Which establishments have a hygiene score equal to 20?**

# %% [markdown]
# ### Number of Establishments from `count_documents`

# %%
# These lines of code query and display the number of establishments 
# with the lowest hygiene score, 20.
queryDictionary \
    = {'scores.Hygiene': 20}

numberOfEstablishmentsInteger \
    = currentPyMongoCollectionObject \
        .count_documents \
            (queryDictionary)

log_subroutine \
    .PrintAndLogWriteText \
        ('There are {:,} establishments with a hygiene score equal to 20.' \
            .format \
                (numberOfEstablishmentsInteger))
# Out:
# There are 41 establishments with a hygiene score equal to 20.

# %% [markdown]
# ### Display First Document

# %%
# This query returns all the documents where the restaurant 
# has a hygiene score equal to 20.
queryResultsDictionaryList \
    = currentPyMongoCollectionObject \
        .find \
            (queryDictionary)


# This line of code displays the first document from the query 
# results.
pprint \
    (queryResultsDictionaryList[0])
# Out:
# {'AddressLine1': '5-6 Southfields Road',
#  'AddressLine2': 'Eastbourne',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'BusinessName': 'The Chase Rest Home',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4613.888288172291,
#  'FHRSID': 110681,
#  'LocalAuthorityBusinessID': '4029',
#  'LocalAuthorityCode': '102',
#  'LocalAuthorityEmailAddress': 'Customerfirst@eastbourne.gov.uk',
#  'LocalAuthorityName': 'Eastbourne',
#  'LocalAuthorityWebSite': 'http://www.eastbourne.gov.uk/foodratings',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'BN21 1BU',
#  'RatingDate': '2021-09-23T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': None,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('650a6b8c5bc6d3e250bfac6f'),
#  'geocode': {'latitude': 50.769705, 'longitude': 0.27694},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/110681',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 20}}

# %% [markdown]
# ### Worst Hygiene Establishments DataFrame

# %%
worstHygieneDataFrame \
    = pd \
        .DataFrame \
            (list \
                (queryResultsDictionaryList))


log_function \
    .DebugReturnObjectWriteObject \
        (worstHygieneDataFrame)

# %% [markdown]
# ### Number of Rows in Worst Hygiene Establishments DataFrame

# %%
log_subroutine \
    .PrintAndLogWriteText \
        ('The number of rows in the Lowest Hygiene Establishments ' \
         + 'DataFrame is {:,}.' \
                .format \
                    (len \
                         (worstHygieneDataFrame)))
# Out:
# The number of rows in the Lowest Hygiene Establishments DataFrame is 41.

# %% [markdown]
# ### Display Worst Hygiene Establishments DataFrame

# %%
function \
    .ReturnStylerObjectStandardFormat \
        (worstHygieneDataFrame.head(10),
         'Table 2.1: Worst Hygiene Establishments',
         hideFlagBooleanParameter = True) \
            .hide \
                ('meta', axis = 1)
# Out:
# <style type="text/css">
# #T_5d2e5 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_5d2e5_row0_col0, #T_5d2e5_row0_col1, #T_5d2e5_row0_col2, #T_5d2e5_row0_col3, #T_5d2e5_row0_col4, #T_5d2e5_row0_col5, #T_5d2e5_row0_col6, #T_5d2e5_row0_col7, #T_5d2e5_row0_col8, #T_5d2e5_row0_col9, #T_5d2e5_row0_col10, #T_5d2e5_row0_col11, #T_5d2e5_row0_col12, #T_5d2e5_row0_col13, #T_5d2e5_row0_col14, #T_5d2e5_row0_col15, #T_5d2e5_row0_col16, #T_5d2e5_row0_col17, #T_5d2e5_row0_col18, #T_5d2e5_row0_col19, #T_5d2e5_row0_col20, #T_5d2e5_row0_col21, #T_5d2e5_row0_col22, #T_5d2e5_row0_col23, #T_5d2e5_row0_col24, #T_5d2e5_row0_col25, #T_5d2e5_row0_col27, #T_5d2e5_row1_col0, #T_5d2e5_row1_col1, #T_5d2e5_row1_col2, #T_5d2e5_row1_col3, #T_5d2e5_row1_col4, #T_5d2e5_row1_col5, #T_5d2e5_row1_col6, #T_5d2e5_row1_col7, #T_5d2e5_row1_col8, #T_5d2e5_row1_col9, #T_5d2e5_row1_col10, #T_5d2e5_row1_col11, #T_5d2e5_row1_col12, #T_5d2e5_row1_col13, #T_5d2e5_row1_col14, #T_5d2e5_row1_col15, #T_5d2e5_row1_col16, #T_5d2e5_row1_col17, #T_5
_row5_col16, #T_5d2e5_row5_col17, #T_5d2e5_row5_col18, #T_5d2e5_row5_col19, #T_5d2e5_row5_col20, #T_5d2e5_row5_col21, #T_5d2e5_row5_col22, #T_5d2e5_row5_col23, #T_5d2e5_row5_col24, #T_5d2e5_row5_col25, #T_5d2e5_row5_col27, #T_5d2e5_row6_col0, #T_5d2e5_row6_col1, #T_5d2e5_row6_col2, #T_5d2e5_row6_col3, #T_5d2e5_row6_col4, #T_5d2e5_row6_col5, #T_5d2e5_row6_col6, #T_5d2e5_row6_col7, #T_5d2e5_row6_col8, #T_5d2e5_row6_col9, #T_5d2e5_row6_col10, #T_5d2e5_row6_col11, #T_5d2e5_row6_col12, #T_5d2e5_row6_col13, #T_5d2e5_row6_col14, #T_5d2e5_row6_col15, #T_5d2e5_row6_col16, #T_5d2e5_row6_col17, #T_5d2e5_row6_col18, #T_5d2e5_row6_col19, #T_5d2e5_row6_col20, #T_5d2e5_row6_col21, #T_5d2e5_row6_col22, #T_5d2e5_row6_col23, #T_5d2e5_row6_col24, #T_5d2e5_row6_col25, #T_5d2e5_row6_col27, #T_5d2e5_row7_col0, #T_5d2e5_row7_col1, #T_5d2e5_row7_col2, #T_5d2e5_row7_col3, #T_5d2e5_row7_col4, # ...
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# </style>
# <table id="T_5d2e5">
#   <caption>Table 2.1: Worst Hygiene Establishments</caption>
#   <thead>
#     <tr>
#       <th id="T_5d2e5_level0_col0" class="col_heading level0 col0" >_id</th>
#       <th id="T_5d2e5_level0_col1" class="col_heading level0 col1" >FHRSID</th>
#       <th id="T_5d2e5_level0_col2" class="col_heading level0 col2" >ChangesByServerID</th>
#       <th id="T_5d2e5_level0_col3" class="col_heading level0 col3" >LocalAuthorityBusinessID</th>
#       <th id="T_5d2e5_level0_col4" class="col_heading level0 col4" >BusinessName</th>
#       <th id="T_5d2e5_level0_col5" class="col_heading level0 col5" >BusinessType</th>
#       <th id="T_5d2e5_level0_col6" class="col_heading level0 col6" >BusinessTypeID</th>
#       <th id="T_5d2e5_level0_col7" class="col_heading level0 col7" >AddressLine1</th>
#       <th id="T_5d2e5_level0_col8" class="col_heading level0 col8" >AddressLine2</th>
#       <th id="T_5d2e5_level0_col9" class="col_heading level0 col9" >AddressLine3</th>
#       <th id="T_5d2e5_level0_col10" class="col_heading level0 col10" >AddressLine4</th>
#       <th id="T_5d2e5_level0_col11" class="col_heading level0 col11" >PostCode</th>
#       <th id="T_5d2e5_level0_col12" class="col_heading level0 col12" >Phone</th>
#       <th id="T_5d2e5_level0_col13" class="col_heading level0 col13" >RatingValue</th>
#       <th id="T_5d2e5_level0_col14" class="col_heading level0 col14" >RatingKey</th>
#       <th id="T_5d2e5_level0_col15" class="col_heading level0 col15" >RatingDate</th>
#       <th id="T_5d2e5_level0_col16" class="col_heading level0 col16" >LocalAuthorityCode</th>
#       <th id="T_5d2e5_level0_col17" class="col_heading level0 col17" >LocalAuthorityName</th>
#       <th id="T_5d2e5_level0_col18" class="col_heading level0 col18" >LocalAuthorityWebSite</th>
#       <th id="T_5d2e5_level0_col19" class="col_heading level0 col19" >LocalAuthorityEmailAddress</th>
#       <th id="T_5d2e5_level0_col20" class="col_heading level0 col20" >scores</th>
#       <th id="T_5d2e5_level0_col21" class="col_heading level0 col21" >SchemeType</th>
#       <th id="T_5d2e5_level0_col22" class="col_heading level0 col22" >geocode</th>
#       <th id="T_5d2e5_level0_col23" class="col_heading level0 col23" >RightToReply</th>
#       <th id="T_5d2e5_level0_c

# %% [markdown]
# ## 2. Which establishments in London have a rating value greater than or equal to 4?

# %% [markdown]
# ### Number of Establishments from `count_documents`

# %%
# These lines of code query and display the number of establishments 
# in London where the 'RatingValue' field has a value greater than
# or equal to 4.
queryDictionary \
    = {'LocalAuthorityName': 
           {'$regex': 'London'}, 
            'RatingValue': {'$gte':4}}

numberOfEstablishmentsInteger \
    = currentPyMongoCollectionObject \
        .count_documents \
            (queryDictionary)

log_subroutine \
    .PrintAndLogWriteText \
        ('There are {:,} establishments with a rating value greater than ' \
             .format \
                (numberOfEstablishmentsInteger) \
         + 'or equal to 4.')
# Out:
# There are 33 establishments with a rating value greater than or equal to 4.

# %% [markdown]
# ### Display First Document

# %%
# This query returns all the documents where the establishment
# is in London and the 'RatingValue' field has a value greater 
# than or equal to 4.
queryResultsDictionaryList \
    = currentPyMongoCollectionObject \
        .find \
            (queryDictionary)


# This line of code displays the first document from the query 
# results.
pprint \
    (queryResultsDictionaryList[0])
# Out:
# {'AddressLine1': 'Oak Apple Farm Building 103 Sheernes Docks',
#  'AddressLine2': 'Sheppy Kent',
#  'AddressLine3': '',
#  'AddressLine4': '',
#  'BusinessName': "Charlie's",
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4627.439467780196,
#  'FHRSID': 621707,
#  'LocalAuthorityBusinessID': 'PI/000025307',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'ME12',
#  'RatingDate': '2021-10-18T00:00:00',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingValue': 4,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('650a6b8c5bc6d3e250bfc68a'),
#  'geocode': {'latitude': 51.369321, 'longitude': 0.508551},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/621707',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 10}}

# %% [markdown]
# ### High Rating Value, London DataFrame

# %%
highRatingLondonDataFrame \
    = pd \
        .DataFrame \
            (list \
                 (queryResultsDictionaryList))


log_function \
    .DebugReturnObjectWriteObject \
        (highRatingLondonDataFrame)

# %% [markdown]
# ### Number of Rows in High Rating Value, London DataFrame

# %%
log_subroutine \
    .PrintAndLogWriteText \
        ('The number of rows in the High Rating Value, London DataFrame is {:,}.' \
            .format \
                (len \
                     (highRatingLondonDataFrame)))
# Out:
# The number of rows in the High Rating Value, London DataFrame is 33.

# %% [markdown]
# ### Display High Rating Value, London DataFrame

# %%
function \
    .ReturnStylerObjectStandardFormat \
        (highRatingLondonDataFrame.head(10),
         'Table 2.2: High Rating Value, London Establishments',
         hideFlagBooleanParameter = True) \
            .hide \
                ('meta', axis = 1)
# Out:
# <style type="text/css">
# #T_9cb72 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_9cb72_row0_col0, #T_9cb72_row0_col1, #T_9cb72_row0_col2, #T_9cb72_row0_col3, #T_9cb72_row0_col4, #T_9cb72_row0_col5, #T_9cb72_row0_col6, #T_9cb72_row0_col7, #T_9cb72_row0_col8, #T_9cb72_row0_col9, #T_9cb72_row0_col10, #T_9cb72_row0_col11, #T_9cb72_row0_col12, #T_9cb72_row0_col13, #T_9cb72_row0_col14, #T_9cb72_row0_col15, #T_9cb72_row0_col16, #T_9cb72_row0_col17, #T_9cb72_row0_col18, #T_9cb72_row0_col19, #T_9cb72_row0_col20, #T_9cb72_row0_col21, #T_9cb72_row0_col22, #T_9cb72_row0_col23, #T_9cb72_row0_col24, #T_9cb72_row0_col25, #T_9cb72_row0_col27, #T_9cb72_row1_col0, #T_9cb72_row1_col1, #T_9cb72_row1_col2, #T_9cb72_row1_col3, #T_9cb72_row1_col4, #T_9cb72_row1_col5, #T_9cb72_row1_col6, #T_9cb72_row1_col7, #T_9cb72_row1_col8, #T_9cb72_row1_col9, #T_9cb72_row1_col10, #T_9cb72_row1_col11, #T_9cb72_row1_col12, #T_9cb72_row1_col13, #T_9cb72_row1_col14, #T_9cb72_row1_col15, #T_9cb72_row1_col16, #T_9cb72_row1_col17, #T_9cb72_row1_col18, #T_9cb72_row1_col19, #T_9cb72_row1_col20, #T_9cb72_row1_col21, #T_9cb72_row1_col22, #T_9cb72_row1_col23, #T_9cb72_row1_col24, #T_9cb72_row1_col25, #T_9cb72_row1_col27, #T_9cb72_row2_col0, #T_9cb72_row2_col1, #T_9cb72_row2_col2, #T_9cb72_row2_col3, #T_9cb72_row2_col4, #T_9cb72_row2_col5, #T_9cb72_row2_col6, #T_9cb72_row2_
6_col13, #T_9cb72_row6_col14, #T_9cb72_row6_col15, #T_9cb72_row6_col16, #T_9cb72_row6_col17, #T_9cb72_row6_col18, #T_9cb72_row6_col19, #T_9cb72_row6_col20, #T_9cb72_row6_col21, #T_9cb72_row6_col22, #T_9cb72_row6_col23, #T_9cb72_row6_col24, #T_9cb72_row6_col25, #T_9cb72_row6_col27, #T_9cb72_row7_col0, #T_9cb72_row7_col1, #T_9cb72_row7_col2, #T_9cb72_row7_col3, #T_9cb72_row7_col4, # ...
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# </style>
# <table id="T_9cb72">
#   <caption>Table 2.2: High Rating Value, London Establishments</caption>
#   <thead>
#     <tr>
#       <th id="T_9cb72_level0_col0" class="col_heading level0 col0" >_id</th>
#       <th id="T_9cb72_level0_col1" class="col_heading level0 col1" >FHRSID</th>
#       <th id="T_9cb72_level0_col2" class="col_heading level0 col2" >ChangesByServerID</th>
#       <th id="T_9cb72_level0_col3" class="col_heading level0 col3" >LocalAuthorityBusinessID</th>
#       <th id="T_9cb72_level0_col4" class="col_heading level0 col4" >BusinessName</th>
#       <th id="T_9cb72_level0_col5" class="col_heading level0 col5" >BusinessType</th>
#       <th id="T_9cb72_level0_col6" class="col_heading level0 col6" >BusinessTypeID</th>
#       <th id="T_9cb72_level0_col7" class="col_heading level0 col7" >AddressLine1</th>
#       <th id="T_9cb72_level0_col8" class="col_heading level0 col8" >AddressLine2</th>
#       <th id="T_9cb72_level0_col9" class="col_heading level0 col9" >AddressLine3</th>
#       <th id="T_9cb72_level0_col10" class="col_heading level0 col10" >AddressLine4</th>
#       <th id="T_9cb72_level0_col11" class="col_heading level0 col11" >PostCode</th>
#       <th id="T_9cb72_level0_col12" class="col_heading level0 col12" >Phone</th>
#       <th id="T_9cb72_level0_col13" class="col_heading level0 col13" >RatingValue</th>
#       <th id="T_9cb72_level0_col14" class="col_heading level0 col14" >RatingKey</th>
#       <th id="T_9cb72_level0_col15" class="col_heading level0 col15" >RatingDate</th>
#       <th id="T_9cb72_level0_col16" class="col_heading level0 col16" >LocalAuthorityCode</th>
#       <th id="T_9cb72_level0_col17" class="col_heading level0 col17" >LocalAuthorityName</th>
#       <th id="T_9cb72_level0_col18" class="col_heading level0 col18" >LocalAuthorityWebSite</th>
#       <th id="T_9cb72_level0_col19" class="col_heading level0 col19" >LocalAuthorityEmailAddress</th>
#       <th id="T_9cb72_level0_col20" class="col_heading level0 col20" >scores</th>
#       <th id="T_9cb72_level0_col21" class="col_heading level0 col21" >SchemeType</th>
#       <th id="T_9cb72_level0_col22" class="col_heading level0 col22" >geocode</th>
#       <th id="T_9cb72_level0_col23" class="col_heading level0 col23" >RightToReply</th>
#       <th id="T_9c

# %% [markdown]
# ## 3. What are the top 5 establishments with a rating value of 5, sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?

# %% [markdown]
# ### Penang Flavours Latitude and Longitude

# %%
# This line of code retrieves the Penang Flavours's document fields, 
# 'latitude' and 'longitude'.
penangFlavoursCoordinatesDictionary \
    = currentPyMongoCollectionObject \
        .find_one \
            ({'BusinessName':'Penang Flavours'}, 
             ['geocode.longitude', 
              'geocode.latitude'])


# This line of code extracts the Penang Flavours's 'latitude' field value.
latitudeFloat \
    = penangFlavoursCoordinatesDictionary \
        ['geocode'] \
        ['latitude']


# This line of code extracts the Penang Flavours's 'longitude' field value.
longitudeFloat \
    = penangFlavoursCoordinatesDictionary \
        ['geocode'] \
        ['longitude']

# %% [markdown]
# ### Query Search Range

# %%
# This line of code establishes the search range as ±0.01 degrees.
degreeSearchFloat = 0.01


# These lines of code calculate and assign the minimum and maximum latitude.
minimumLatitudeFloat \
    = latitudeFloat - degreeSearchFloat

maximumLatitudeFloat \
    = latitudeFloat + degreeSearchFloat


# These lines of code calculate and assign the minimum and maximum longitude.
minimumLongitudeFloat \
    = longitudeFloat - degreeSearchFloat

maximumLongitudeFloat \
    = longitudeFloat + degreeSearchFloat

# %% [markdown]
# ### Query Results

# %%
# These Dictionaries are the query parameters.
queryDictionary \
    = {'RatingValue': 5,
       'geocode.latitude': \
           {'$gte': minimumLatitudeFloat, '$lte': maximumLatitudeFloat},
       'geocode.longitude': \
           {'$gte': minimumLongitudeFloat, '$lte': maximumLongitudeFloat}}
       
sortValuesTupleList \
    = [('scores.Hygiene', 1)]
       
limitInteger \
    = 5


# This query returns the top 5 establishments with a 'RatingValue' field
# value of 5, sorted by lowest hygiene score, nearest to the restaurant,
# 'Penang Flavours'.
resultsPyMongoCursorList \
    = list \
        (currentPyMongoCollectionObject \
            .find \
                (queryDictionary) \
            .sort \
                 (sortValuesTupleList) \
            .limit \
                 (limitInteger))


log_function \
    .DebugReturnObjectWriteObject \
        (resultsPyMongoCursorList)

# %% [markdown]
# ### Number of Establishments from `count_documents`

# %%
numberOfEstablishmentsInteger \
    = currentPyMongoCollectionObject \
        .count_documents \
            (queryDictionary, 
             limit \
                 = limitInteger)

log_subroutine \
    .PrintAndLogWriteText \
        ('Due to the query parameter limiting the number of results, ' \
         + 'there are {:,} establishments with a rating value of 5.' \
            .format \
                (numberOfEstablishmentsInteger))
# Out:
# Due to the query parameter limiting the number of results, there are 5 establishments with a rating value of 5.

# %% [markdown]
# ### Display All Documents

# %%
pprint \
    (resultsPyMongoCursorList)
# Out:
# [{'AddressLine1': 'Restaurant And Premises 107A Plumstead High Street',
#   'AddressLine2': '',
#   'AddressLine3': 'Plumstead',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Howe and Co Fish and Chips - Van 17',
#   'BusinessType': 'Mobile caterer',
#   'BusinessTypeID': 7846,
#   'ChangesByServerID': 0,
#   'Distance': 4646.95593107927,
#   'FHRSID': 1380578,
#   'LocalAuthorityBusinessID': '14425',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 1SE',
#   'RatingDate': '2021-11-11T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('650a6b8c5bc6d3e250c004b1'),
#   'geocode': {'latitude': 51.4875335693359, 'longitude': 0.0925370007753372},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1380578',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}},
#  {'AddressLine1': '35 Lakedale Road',
#   'AddressLine2': '',
#   'AddressLine3': 'Plumstead',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Atlantic Fish Bar',
#   'BusinessType': 'Takeaway/sandwich shop',
#   'BusinessTypeID': 7844,
#   'ChangesByServerID': 0,
#   'Distance': 4646.974611855838,
#   'FHRSID': 694478,
#   'LocalAuthorityBusinessID': 'PI/000086506',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 1PR',
#   'RatingDate': '2021-06-16T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('650a6b8c5bc6d3e250c004e9'),
#   'geocode': {'latitude': 51.4867296, 'longitude': 0.0912164},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/694478',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 0}},
#  {'AddressLine1': 'Plumstead Manor School Old Mill Road',
#   'AddressLine2': '',
#   'AddressLine3': 'Plumstead',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Plumstead Manor Nursery',
#   'BusinessType': 'Caring Premises',
#   'BusinessTypeID': 5,
#   'ChangesByServerID': 0,
#   'Distance': 4646.9740101340385,
#   'FHRSID': 695241,
#   'LocalAuthorityBusinessID': 'PI/000179088',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 1QG',
#   'RatingDate': '2021-06-16T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('650a6b8c5bc6d3e250c004e6'),
#   'geocode': {'latitude': 51.481517791748, 'longitude': 0.0859939977526665},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/695241',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 0}},
#  {'AddressLine1': '144 - 146 Plumstead High Street',
#   'AddressLine2': '',
#   'AddressLine3': 'Plumstead',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Iceland',
#   'BusinessType': 'Retailers - supermarkets/hypermarkets',
#   'BusinessTypeID': 7840,
#   'ChangesByServerID': 0,
#   'Distance': 4646.946071297699,
#   'FHRSID': 695223,
#   'LocalAuthorityBusinessID': 'PI/000178842',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 1JQ',
#   'RatingDate': '2019-11-13T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('650a6b8c5bc6d3e250c004a1'),
#   'geocode': {'latitude': 51.4871482849121, 'longitude': 0.0924199968576431},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/695223',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 5}},
#  {'AddressLine1': '130 - 132 Plumstead High Street',
#   'AddressLine2': '',
#   'AddressLine3': 'Plumstead',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Volunteer',
#   'BusinessType': 'Pub/bar/nightclub',
#   'BusinessTypeID': 7843,
#   'ChangesByServerID': 0,
#   'Distance': 4646.965634598608,
#   'FHRSID': 694609,
#   'LocalAuthorityBusinessID': 'PI/000116619',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 1JQ',
#   'RatingDate': '2019-08-05T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('650a6b8c5bc6d3e250c004ce'),
#   'geocode': {'latitude': 51.4873437, 'longitude': 0.09208},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/694609',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}]

# %% [markdown]
# ### Highest Rating, Best Hygiene Establishments DataFrame

# %%
highRatingBestHygieneDataFrame \
    = pd \
        .DataFrame \
            (resultsPyMongoCursorList)


log_function \
    .DebugReturnObjectWriteObject \
        (highRatingBestHygieneDataFrame)

# %% [markdown]
# ### Number of Rows in Highest Rating, Best Hygiene Establishments DataFrame

# %%
log_subroutine \
    .PrintAndLogWriteText \
        ('The number of rows in the Highest Rating, Best Hygiene DataFrame is {:,}.' \
            .format \
                (len \
                     (highRatingBestHygieneDataFrame)))
# Out:
# The number of rows in the Highest Rating, Best Hygiene DataFrame is 5.

# %% [markdown]
# ### Display Highest Rating, Best Hygiene Establishments DataFrame

# %%
function \
    .ReturnStylerObjectStandardFormat \
        (highRatingBestHygieneDataFrame,
         'Table 2.3: Highest Rating, Best Hygiene Establishments',
         hideFlagBooleanParameter = True) \
            .hide \
                ('meta', axis = 1)
# Out:
# <style type="text/css">
# #T_37fa3 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_37fa3_row0_col0, #T_37fa3_row0_col1, #T_37fa3_row0_col2, #T_37fa3_row0_col3, #T_37fa3_row0_col4, #T_37fa3_row0_col5, #T_37fa3_row0_col6, #T_37fa3_row0_col7, #T_37fa3_row0_col8, #T_37fa3_row0_col9, #T_37fa3_row0_col10, #T_37fa3_row0_col11, #T_37fa3_row0_col12, #T_37fa3_row0_col13, #T_37fa3_row0_col14, #T_37fa3_row0_col15, #T_37fa3_row0_col16, #T_37fa3_row0_col17
{
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# </style>
# <table id="T_37fa3">
#   <caption>Table 2.3: Highest Rating, Best Hygiene Establishments</caption>
#   <thead>
#     <tr>
#       <th id="T_37fa3_level0_col0" class="col_heading level0 col0" >_id</th>
#       <th id="T_37fa3_level0_col1" class="col_heading level0 col1" >FHRSID</th>
#       <th id="T_37fa3_level0_col2" class="col_heading level0 col2" >ChangesByServerID</th>
#       <th id="T_37fa3_level0_col3" class="col_heading level0 col3" >LocalAuthorityBusinessID</th>
#       <th id="T_37fa3_level0_col4" class="col_heading level0 col4" >BusinessName</th>
#       <th id="T_37fa3_level0_col5" class="col_heading level0 col5" >BusinessType</th>
#       <th id="T_37fa3_level0_col6" class="col_heading level0 col6" >BusinessTypeID</th>
#       <th id="T_37fa3_level0_col7" class="col_heading level0 col7" >AddressLine1</th>
#       <th id="T_37fa3_level0_col8" class="col_heading level0 col8" >AddressLine2</th>
#       <th id="T_37fa3_level0_col9" class="col_heading level0 col9" >AddressLine3</th>
#       <th id="T_37fa3_level0_col10" class="col_heading level0 col10" >AddressLine4</th>
#       <th id="T_37fa3_level0_col11" class="col_heading level0 col11" >PostCode</th>
#       <th id="T_37fa3_level0_col12" class="col_heading level0 col12" >Phone</th>
#       <th id="T_37fa3_level0_col13" class="col_heading level0 col13" >RatingValue</th>
#       <th id="T_37fa3_level0_col14" class="col_heading level0 col14" >RatingKey</th>
#       <th id="T_37fa3_level0_col15" class="col_heading level0 col15" >RatingDate</th>
#       <th id="T_37fa3_level0_col16" class="col_heading level0 col16" >LocalAuthorityCode</th>
#       <th id="T_37fa3_level0_col17" class="col_heading level0 col17" >LocalAuthorityName</th>
#       <th id="T_37fa3_level0_col18" class="col_heading level0 col18" >LocalAuthorityWebSite</th>
#       <th id="T_37fa3_level0_col19" class="col_heading level0 col19" >LocalAuthorityEmailAddress</th>
#       <th id="T_37fa3_level0_col20" class="col_heading level0 col20" >scores</th>
#       <th id="T_37fa3_level0_col21" class="col_heading level0 col21" >SchemeType</th>
#       <th id="T_37fa3_level0_col22" class="col_heading level0 col22" >geocode</th>
#       <th id="T_37fa3_level0_col23" class="col_heading level0 col23" >RightToReply</th>
#       <th id="T_37fa3_level0_col24" class="col_heading level0 col24" >Distance</th>
#       <th id="T_37fa3_level0_col25" class="col_heading level0 col25" >NewRatingPending</th>
#       <th id="T_37fa3_level0_col27" class="col_heading level0 col27" >links</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_37fa3_row0_col0" class="data row0 col0" >650a6b8c5bc6d3e250c004b1</td>
#       <td id="T_37fa3_row0_col1" class="data row0 col1" >1,380,578</td>
#       <td id="T_37fa3_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_37fa3_row0_col3" class="data row0 col3" >14425</td>
#       <td id="T_37fa3_row0_col4" class="data row0 col4" >Howe and Co Fish and Chips - Van 17</td>
#       <td id="T_37fa3_row0_col5" class="data row0 col5" >Mobile caterer</td>
#       <td id="T_37fa3_row0_col6" class="data row0 col6" >7,846</td>
#       <td id="T_37fa3_row0_col7" class="data row0 col7" >Restaurant And Premises 107A Plumstead High Street</td>
#       <td id="T_37fa3_row0_col8" class="data row0 col8" ></td>
#       <td id="T_37fa3_row0_col9" class="data row0 col9" >Plumstead</td>
#       <td id="T_37fa3_row0_col10" class="data row0 col10" >Greenwich</td>
#       <td id="T_37fa3_row0_col11" class="data row0 col11" >SE18 1SE</td>
#       <td id="T_37fa3_row0_col12" class="data row0 col12" ></td>
#       <td id="T_37fa3_row0_col13" class="data row0 col13" >5</td>
#       <td id="T_37fa3_row0_col14" class="data row0 col14" >fhrs_5_en-gb</td>
#       <td id="T_37fa3_row0_col15" class="data row0 col15" >2021-11-11T00:00:00</td>
#       <td id="T_37fa3_row0_col16" class="data row0 col16" >511</td>
#       <td id="T_37fa3_row0_col17" class="data row0 col17" >Greenwich</td>
#       <td id="T_37fa3_row0_col18" class="data row0 col18" >http://www.royalgreenwich.gov.uk</td>
#       <td id="T_37fa3_row0_col19" class="data row0 col19" >health@royalgreenwich.gov.uk</td>
#       <td id="T_37fa3_row0_col20" class="data row0 col20" >{'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 0}</td>
#       <td id="T_37fa3_row0_col21" class="data row0 col21" >FHRS</td>
#       <td id="T_37fa3_row0_col22" class="data row0 col22" >{'longitude': 0.0925370007753372, 'latitude': 51.4875335693359}</td>
#       <td id="T_37fa3_row0_col23" class="data row0 col23" ></td>
#       <td id="T_37fa3_row0_col24" class="data row0 col24" >4,646.96</td>
#       <td id="T_37fa3_row0_col25" class="data row0 col25" >False</td>
#       <td id="T_37fa3_row0_col27" class="data row0 col27" >[{'rel': 'self', 'href': 'http://api.ratings.food.gov.uk/establishments/1380578'}]</td>
#     </tr>
#     <tr>
#       <td id="T_37fa3_row1_col0" class="data row1 col0" >650a6b8c5bc6d3e250c004e9</td>
#       <td id="T_37fa3_row1_col1" class="data row1 col1" >694,478</td>
#       <td id="T_37fa3_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_37fa3_row1_col3"

# %% [markdown]
# ## 4. How many establishments in each Local Authority area have a hygiene score of 0?

# %% [markdown]
# ### Query Parameters

# %%
# 1. This Dictionary matches establishments with a hygiene score of 0.
matchQueryDictionary \
    = {'$match': {'scores.Hygiene': 0}}

# 2. This Dictionary groups the matches by Local Authority and counts 
# how many establishments meet the match criteria for each Local Authority.
groupQueryDictionary \
    = {'$group': \
           {'_id': '$LocalAuthorityName', 
            'count': {'$sum': 1}}}

# 3. This Dictionary sorts the matches in descending order 
# (from highest to lowest) based on count.
sortValuesDictionary \
    = {'$sort': {'count': -1}}

pipeLineList \
    = [matchQueryDictionary, 
       groupQueryDictionary, 
       sortValuesDictionary]

# %% [markdown]
# ### Query Results

# %%
resultsPyMongoCommandCursorList \
    = list \
        (currentPyMongoCollectionObject \
             .aggregate \
                 (pipeLineList))


log_function \
    .DebugReturnObjectWriteObject \
        (resultsPyMongoCommandCursorList)

# %% [markdown]
# ### Number of Authorities and Establishments from Aggregation Query Results

# %%
numberOfAuthoritiesInteger \
    = len \
        ([element for element in resultsPyMongoCommandCursorList \
          if isinstance(element, dict)])

numberOfEstablishmentsInteger \
    = sum \
        ([element['count'] for element in resultsPyMongoCommandCursorList \
          if isinstance(element, dict)])

log_subroutine \
    .PrintAndLogWriteText \
        ('From the aggregation query results, there are {:,} ' \
             .format \
                 (numberOfEstablishmentsInteger)
         + 'establishments with a hygiene score of 0 ' \
         + 'in {:,} Local Authorities.' \
                .format \
                    (numberOfAuthoritiesInteger))
# Out:
# From the aggregation query results, there are 16,827 establishments with a hygiene score of 0 in 55 Local Authorities.

# %% [markdown]
# ### Number of Authorities and Establishments from `count_documents`

# %%
numberOfAuthoritiesInteger \
    = len(currentPyMongoCollectionObject \
            .distinct 
                ('LocalAuthorityName',
                 {'scores.Hygiene': 0}))

numberOfEstablishmentsInteger \
    = currentPyMongoCollectionObject \
        .count_documents \
            ({'scores.Hygiene': 0})

log_subroutine \
    .PrintAndLogWriteText \
        ("From the 'count_documents' method, there are {:,} " \
             .format \
                 (numberOfEstablishmentsInteger)
         + 'establishments with a hygiene score of 0 ' \
         + 'in {:,} Local Authorities.' \
                .format \
                    (numberOfAuthoritiesInteger))
# Out:
# From the 'count_documents' method, there are 16,827 establishments with a hygiene score of 0 in 55 Local Authorities.

# %% [markdown]
# ### Display Documents

# %%
pprint \
    (resultsPyMongoCommandCursorList[0:10])
# Out:
# [{'_id': 'Thanet', 'count': 1130},
#  {'_id': 'Greenwich', 'count': 882},
#  {'_id': 'Maidstone', 'count': 713},
#  {'_id': 'Newham', 'count': 711},
#  {'_id': 'Swale', 'count': 686},
#  {'_id': 'Chelmsford', 'count': 680},
#  {'_id': 'Medway', 'count': 672},
#  {'_id': 'Bexley', 'count': 607},
#  {'_id': 'Southend-On-Sea', 'count': 586},
#  {'_id': 'Tendring', 'count': 542}]

# %% [markdown]
# ### Highest Hygiene DataFrame

# %%
highestHygieneScoreDataFrame \
    = pd \
        .DataFrame \
            (resultsPyMongoCommandCursorList)


log_function \
    .DebugReturnObjectWriteObject \
        (highestHygieneScoreDataFrame)

# %%
log_subroutine \
    .PrintAndLogWriteText \
        ('The number of rows in the Highest Hygiene DataFrame is {:,}.' \
            .format \
                (len \
                     (highestHygieneScoreDataFrame)))
# Out:
# The number of rows in the Highest Hygiene DataFrame is 55.

# %%
function \
    .ReturnStylerObjectStandardFormat \
        (highestHygieneScoreDataFrame.head(10),
         'Table 2.4: Local Authorities with Number of Establishments ' \
         + 'with Highest Hygiene Score',
         hideFlagBooleanParameter = True) \
            .hide()
# Out:
# <style type="text/css">
# #T_61504 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_61504_row0_col0, #T_61504_row0_col1, #T_61504_row1_col0, #T_61504_row1_col1, #T_61504_row2_col0, #T_61504_row2_col1, #T_61504_row3_col0, #T_61504_row3_col1, #T_61504_row4_col0, #T_61504_row4_col1, #T_61504_row5_col0, #T_61504_row5_col1, #T_61504_row6_col0, #T_61504_row6_col1, #T_61504_row7_col0, #T_61504_row7_col1, #T_61504_row8_col0, #T_61504_row8_col1, #T_61504_row9_col0, #T_61504_row9_col1 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# </style>
# <table id="T_61504">
#   <caption>Table 2.4: Local Authorities with Number of Establishments with Highest Hygiene Score</caption>
#   <thead>
#     <tr>
#       <th id="T_61504_level0_col0" class="col_heading level0 col0" >_id</th>
#       <th id="T_61504_level0_col1" class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_61504_row0_col0" class="data row0 col0" >Thanet</td>
#       <td id="T_61504_row0_col1" class="data row0 col1" >1,130</td>
#     </tr>
#     <tr>
#       <td id="T_61504_row1_col0" class="data row1 col0" >Greenwich</td>
#       <td id="T_61504_row1_col1" class="data row1 col1" >882</td>
#     </tr>
#     <tr>
#       <td id="T_61504_row2_col0" class="data row2 col0" >Maidstone</td>
#       <td id="T_61504_row2_col1" class="data row2 col1" >713</td>
#     </tr>
#     <tr>
#       <td id="T_61504_row3_col0" class="data row3 col0" >Newham</td>
#       <td id="T_61504_row3_col1" class="data row3 col1" >711</td>
#     </tr>
#     <tr>
#       <td id="T_61504_row4_col0" class="data row4 col0" >Swale</td>
#       <td id="T_61504_row4_col1" class="data row4 col1" >686</td>
#     </tr>
#     <tr>
#       <td id="T_61504_row5_col0" class="data row5 col0" >Chelmsford</td>
#       <td id="T_61504_row5_col1" class="data row5 col1" >680</td>
#     </tr>
#     <tr>
#       <td id="T_61504_row6_col0" class="data row6 col0" >Medway</td>
#       <td id="T_61504_row6_col1" class="data row6 col1" >672</td>
#     </tr>
#     <tr>
#       <td id="T_61504_row7_col0" class="data row7 col0" >Bexley</td>
#       <td id="T_61504_row7_col1" class="data row7 col1" >607</td>
#     </tr>
#     <tr>
#       <td id="T_61504_row8_col0" class="data row8 col0" >Southend-On-Sea</td>
#       <td id="T_61504_row8_col1" class="data row8 col1" >586</td>
#     </tr>
#     <tr>
#       <td id="T_61504_row9_col0" class="data row9 col0" >Tendring</td>
#       <td id="T_61504_row9_col1" class="data row9 col1" >542</td>
#     </tr>
#   </tbody>
# </table>

# %%
#log_subroutine \
#    .EndProgramExecution()
